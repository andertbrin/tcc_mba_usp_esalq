# %%
import os
import sys
import json

from pathlib import Path
from dotenv import load_dotenv


import matplotlib.pyplot as plt

path_proj = Path.cwd().parent
path_data = os.path.join(path_proj, "data")

load_dotenv()

sys.path.append(os.path.join(path_proj, "utils"))

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
neo4j_url = os.getenv("neo4jurl")
neo4j_user = os.getenv("noe4juser")
neo4j_password = os.getenv("neo4jpass")

# %%
from neo4j import GraphDatabase

with GraphDatabase.driver(neo4j_url, auth=(neo4j_user, neo4j_password)) as driver:
    driver.verify_connectivity()
    print("Successfully connected to Neo4j database")
# Out:
# Successfully connected to Neo4j database

# %%
driver = GraphDatabase.driver(neo4j_url, auth=(neo4j_user, neo4j_password))

with driver.session() as session:
    result = session.run("RETURN 1 AS number")
    record = result.single()
    print(f"Test query result: {record['number']}")
# Out:
# Test query result: 1

# %%
import pandas as pd
import ast

df_llm = pd.read_csv(os.path.join(path_data, "result_analysis.csv"))

df_llm["publication_date"] = pd.to_datetime(df_llm["publication_date"])
df_llm["embedding_signal"] = df_llm["embedding_signal"].apply(ast.literal_eval)

df_llm.head()
# Out:
#                                                  url  \
# 0  https://www.federalreserve.gov/newsevents/pres...
# 1  https://www.federalreserve.gov/newsevents/pres...
# 2  https://www.federalreserve.gov/newsevents/pres...
# 3  https://www.federalreserve.gov/newsevents/pres...
# 4  https://www.federalreserve.gov/newsevents/pres...
#
#                                    title publication_date classification  \
# 0  Federal Reserve issues FOMC statement       2026-01-28  mostly_dovish
# 1  Federal Reserve issues FOMC statement       2026-01-28  mostly_dovish
# 2  Federal Reserve issues FOMC statement       2026-01-28        neutral
# 3  Federal Reserve issues FOMC statement       2026-01-28        neutral
# 4  Federal Reserve issues FOMC statement       2026-01-28        neutral
#
#    score                                             signal  \
# 0   -0.5  Low job gains and a stabilizing unemployment r...
# 1   -0.5  Two FOMC members dissented in favor of an imme...
# 2    0.0  The Committee retained a data-dependent approa...
# 3    0.0  The Committee emphasized two-sided risks aroun...
# 4    0.0  The Committee stated it could adjust policy in...
#
#                                        justification  \
# 0  The labor market is no longer described as str...
# 1  The dissents provide a direct, though minority...
# 2  The statement does not pre-commit to either cu...
# 3  Attention to risks on both employment and infl...
# 4  This is a general contingency statement rather...
#
#                                             evidence  \
# 0  Job gains have remained low, and the unemploym...
# 1  Stephen I. Miran and Christopher J. Waller, wh...
# 2  the Committee will carefully assess incoming d...
# 3  The Committee is attentive to the risks to bot...
# 4  prepared to adjust the stance of monetary poli...
#
#                                     embedding_signal
# 0  [-0.039459228515625, -0.01479339599609375, -0....
# 1  [0.010986328125, -0.03143310546875, -0.0175933...
# 2  [-0.0172576904296875, -0.0224761962890625, -0....
# 3  [0.0009055137634277344, -0.0279388427734375, -...
# 4  [-0.006946563720703125, -0.0029315948486328125...

# %%
df_llm.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10452 entries, 0 to 10451
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   url               10452 non-null  str
#  1   title             10452 non-null  str
#  2   publication_date  10452 non-null  datetime64[us]
#  3   classification    10452 non-null  str
#  4   score             10452 non-null  float64
#  5   signal            10452 non-null  str
#  6   justification     10452 non-null  str
#  7   evidence          10452 non-null  str
#  8   embedding_signal  10452 non-null  object
# dtypes: datetime64[us](1), float64(1), object(1), str(6)
# memory usage: 735.0+ KB

# %%
for ind, row in df_llm.iterrows():
    query = """
       MERGE (p:Publication {url: $url})
       SET
            p.title = $title,
            p.publication_date = $publication_date
    """

    records, summary, keys = driver.execute_query(
        query,
        parameters_={
            "url": row["url"],
            "title": row["title"],
            "publication_date": row["publication_date"].to_pydatetime(),
        }
    )

    # query = """
    #     MERGE (d:Date {date: $publication_date})
    #     """
    # records, summary, keys = driver.execute_query(
    #     query,
    #     parameters_={
    #         "publication_date": row["publication_date"].to_pydatetime(),
    #     }
    # )

    # query = """
    #     MATCH (p:Publication {url: $url})
    #     MATCH (d:Date {date: $publication_date})
    #     MERGE (p)-[:PUBLISHED_ON]->(d)
    # """
    # records, summary, keys = driver.execute_query(
    #     query,
    #     parameters_={
    #         "url": row["url"],
    #         "publication_date": row["publication_date"].to_pydatetime(),
    #     }
    # )

    query = """
        MERGE (s:Signal {text: $signal,
                         url: $url})
        SET s.classification = $classification,
            s.score = $score,
            s.justification = $justification,
            s.evidence = $evidence,
            s.embedding_signal = $embedding_signal,
            s.date = $publication_date
    """
    records, summary, keys = driver.execute_query(
        query,
        parameters_={
            "signal": row["signal"],
            "url": row["url"],
            "classification": row["classification"],
            "score": row["score"],
            "justification": row["justification"],
            "evidence": row["evidence"],
            "embedding_signal": row["embedding_signal"],
            "publication_date": row["publication_date"].to_pydatetime(),
        }
    )

    query = """
        MATCH (p:Publication {url: $url})
        MATCH (s:Signal {text: $signal,
                         url: $url})
        MERGE (p)-[:HAS_SIGNAL]->(s)
    """
    records, summary, keys = driver.execute_query(
        query,
        parameters_={
            "url": row["url"],
            "signal": row["signal"],
        }
    )
    print(f"Processed record {ind} with URL: {row['url']}")
# Out:
# Processed record 0 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128a.htm
# Processed record 1 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128a.htm
# Processed record 2 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128a.htm
# Processed record 3 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128a.htm
# Processed record 4 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128a.htm
# Processed record 5 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128a.htm
# Processed record 6 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128a.htm
# Processed record 7 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128a.htm
# Processed record 8 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128a.htm
# Processed record 9 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128a.htm
# Processed record 10 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpressconf20260128.htm
# Processed record 11 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpressconf20260128.htm
# Processed record 12 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpressconf20260128.htm
# Processed record 13 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpressconf20260128.htm
# Processed record 14 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpressconf20260128.htm
# Processed record 15 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpressconf20260128.htm
# Processed record 16 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpressconf20260128.htm
# Processed record 17 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpressconf20260128.htm
# Processed record 18 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpressconf20260128.htm
# Processed record 19 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpressconf20260128.htm
# Processed record 20 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpressconf20260128.htm
# Processed record 21 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpressconf20260128.htm
# Processed record 22 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpressconf20260128.htm
# Processed record 23 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpressconf20260128.htm
# Processed record 24 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpressconf20260128.htm
# Processed record 25 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpressconf20260128.htm
# Processed record 26 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpressconf20260128.htm
# Processed record 27 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpressconf20260128.htm
# Processed record 28 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128b.htm
# Processed record 29 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128b.htm
# Processed record 30 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128b.htm
# Processed record 31 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128b.htm
# Processed record 32 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128b.htm
# Processed record 33 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20251210a.htm
# Processed record 34 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20251210a.htm
# Processed record 35 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20251210a.htm
# Processed record 36 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20251210a.htm
# Processed record 37 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20251210a.htm
# Processed record 38 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20251210a.htm
# Processed record 39 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20251210a.htm
# Processed record 40 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20251210a.htm
# Processed record 41 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20251210a.htm
# Processed record 42 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251210.htm
# Processed record 43 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251210.htm
# Processed record 44 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251210.htm
# Processed record 45 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251210.htm
# Processed record 46 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251210.htm
# Processed record 47 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251210.htm
# Processed record 48 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251210.htm
# Processed record 49 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251210.htm
# Processed record 50 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251210.htm
# Processed record 51 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251210.htm
# Processed record 52 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251210.htm
# Processed record 53 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251210.htm
# Processed record 54 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251210.htm
# Processed record 55 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251210.htm
# Processed record 56 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251210.htm
# Processed record 57 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251210.htm
# Processed record 58 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251210.htm
# Processed record 59 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251210.htm
# Processed record 60 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251210.htm
# Processed record 61 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251210.htm
# Processed record 62 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251210.htm
# Processed record 63 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251210.htm
# Processed record 64 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251210.htm
# Processed record 65 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251210.htm
# Processed record 66 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251210.htm
# Processed record 67 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251210.htm
# Processed record 68 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251210.htm
# Processed record 69 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251210.htm
# Processed record 70 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251210.htm
# Processed record 71 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251210.htm
# Processed record 72 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251210.htm
# Processed record 73 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251210.htm
# Processed record 74 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251210.htm
# Processed record 75 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251210.htm
# Processed record 76 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251210.htm
# Processed record 77 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251210.htm
# Processed record 78 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251210.htm
# Processed record 79 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251210.htm
# Processed record 80 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251210.htm
# Processed record 81 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251210.htm
# Processed record 82 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20251210.htm
# Processed record 83 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20251210.htm
# Processed record 84 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20251210.htm
# Processed record 85 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20251210.htm
# Processed record 86 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20251210.htm
# Processed record 87 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20251210.htm
# Processed record 88 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20251210.htm
# Processed record 89 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20251210.htm
# Processed record 90 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20251210.htm
# Processed record 91 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20251210.htm
# Processed record 92 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20251210.htm
# Processed record 93 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20251210.htm
# Processed record 94 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20251210.htm
# Processed record 95 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20251029a.htm
# Processed record 96 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20251029a.htm
# Processed record 97 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20251029a.htm
# Processed record 98 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20251029a.htm
# Processed record 99 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20251029a.htm
# Processed record 100 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20251029a.htm
# Processed record 101 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20251029a.htm
# Processed record 102 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20251029a.htm
# Processed record 103 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20251029a.htm
# Processed record 104 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20251029a.htm
# Processed record 105 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20251029a.htm
# Processed record 106 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20251029a.htm
# Processed record 107 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251029.htm
# Processed record 108 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251029.htm
# Processed record 109 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251029.htm
# Processed record 110 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251029.htm
# Processed record 111 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251029.htm
# Processed record 112 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251029.htm
# Processed record 113 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251029.htm
# Processed record 114 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251029.htm
# Processed record 115 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251029.htm
# Processed record 116 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251029.htm
# Processed record 117 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251029.htm
# Processed record 118 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251029.htm
# Processed record 119 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251029.htm
# Processed record 120 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251029.htm
# Processed record 121 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251029.htm
# Processed record 122 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251029.htm
# Processed record 123 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251029.htm
# Processed record 124 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251029.htm
# Processed record 125 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251029.htm
# Processed record 126 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20251029.htm
# Processed record 127 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251029.htm
# Processed record 128 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251029.htm
# Processed record 129 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251029.htm
# Processed record 130 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251029.htm
# Processed record 131 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251029.htm
# Processed record 132 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251029.htm
# Processed record 133 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251029.htm
# Processed record 134 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251029.htm
# Processed record 135 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251029.htm
# Processed record 136 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251029.htm
# Processed record 137 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251029.htm
# Processed record 138 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251029.htm
# Processed record 139 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251029.htm
# Processed record 140 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251029.htm
# Processed record 141 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251029.htm
# Processed record 142 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251029.htm
# Processed record 143 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251029.htm
# Processed record 144 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251029.htm
# Processed record 145 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251029.htm
# Processed record 146 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251029.htm
# Processed record 147 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251029.htm
# Processed record 148 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20251029.htm
# Processed record 149 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250917a.htm
# Processed record 150 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250917a.htm
# Processed record 151 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250917a.htm
# Processed record 152 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250917a.htm
# Processed record 153 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250917a.htm
# Processed record 154 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250917a.htm
# Processed record 155 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250917a.htm
# Processed record 156 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250917a.htm
# Processed record 157 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250917a.htm
# Processed record 158 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250917a.htm
# Processed record 159 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250917a.htm
# Processed record 160 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 161 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 162 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 163 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 164 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 165 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 166 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 167 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 168 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 169 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 170 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 171 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 172 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 173 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 174 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 175 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 176 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 177 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 178 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 179 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 180 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 181 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 182 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250917.htm
# Processed record 183 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250917.htm
# Processed record 184 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250917.htm
# Processed record 185 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250917.htm
# Processed record 186 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250917.htm
# Processed record 187 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250917.htm
# Processed record 188 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250917.htm
# Processed record 189 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250917.htm
# Processed record 190 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250917.htm
# Processed record 191 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250917.htm
# Processed record 192 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250917.htm
# Processed record 193 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250917.htm
# Processed record 194 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250917.htm
# Processed record 195 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250917.htm
# Processed record 196 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250917.htm
# Processed record 197 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250917.htm
# Processed record 198 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250917.htm
# Processed record 199 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250917.htm
# Processed record 200 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250917.htm
# Processed record 201 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250917.htm
# Processed record 202 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250917.htm
# Processed record 203 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250917.htm
# Processed record 204 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250917.htm
# Processed record 205 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250917.htm
# Processed record 206 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250917.htm
# Processed record 207 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250917.htm
# Processed record 208 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250917.htm
# Processed record 209 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250917.htm
# Processed record 210 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250917.htm
# Processed record 211 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250917.htm
# Processed record 212 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250917.htm
# Processed record 213 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250917.htm
# Processed record 214 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250917.htm
# Processed record 215 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250917.htm
# Processed record 216 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250917.htm
# Processed record 217 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250917.htm
# Processed record 218 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250917.htm
# Processed record 219 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250822a.htm
# Processed record 220 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250822a.htm
# Processed record 221 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250822a.htm
# Processed record 222 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250822a.htm
# Processed record 223 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250822a.htm
# Processed record 224 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250730a.htm
# Processed record 225 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250730a.htm
# Processed record 226 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250730a.htm
# Processed record 227 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250730a.htm
# Processed record 228 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250730a.htm
# Processed record 229 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250730a.htm
# Processed record 230 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250730a.htm
# Processed record 231 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250730a.htm
# Processed record 232 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250730.htm
# Processed record 233 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250730.htm
# Processed record 234 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250730.htm
# Processed record 235 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250730.htm
# Processed record 236 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250730.htm
# Processed record 237 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250730.htm
# Processed record 238 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250730.htm
# Processed record 239 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250730.htm
# Processed record 240 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250730.htm
# Processed record 241 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250730.htm
# Processed record 242 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250730.htm
# Processed record 243 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250730.htm
# Processed record 244 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250730.htm
# Processed record 245 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250730.htm
# Processed record 246 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250730.htm
# Processed record 247 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250730.htm
# Processed record 248 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250730.htm
# Processed record 249 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250730.htm
# Processed record 250 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250730.htm
# Processed record 251 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250730.htm
# Processed record 252 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250730.htm
# Processed record 253 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250730.htm
# Processed record 254 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250730.htm
# Processed record 255 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250730.htm
# Processed record 256 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250730.htm
# Processed record 257 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250730.htm
# Processed record 258 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250730.htm
# Processed record 259 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250730.htm
# Processed record 260 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250730.htm
# Processed record 261 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250730.htm
# Processed record 262 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250730.htm
# Processed record 263 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250730.htm
# Processed record 264 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250730.htm
# Processed record 265 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250730.htm
# Processed record 266 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250730.htm
# Processed record 267 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250730.htm
# Processed record 268 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250618a.htm
# Processed record 269 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250618a.htm
# Processed record 270 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250618a.htm
# Processed record 271 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250618a.htm
# Processed record 272 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250618a.htm
# Processed record 273 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250618a.htm
# Processed record 274 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250618a.htm
# Processed record 275 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250618a.htm
# Processed record 276 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250618.htm
# Processed record 277 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250618.htm
# Processed record 278 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250618.htm
# Processed record 279 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250618.htm
# Processed record 280 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250618.htm
# Processed record 281 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250618.htm
# Processed record 282 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250618.htm
# Processed record 283 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250618.htm
# Processed record 284 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250618.htm
# Processed record 285 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250618.htm
# Processed record 286 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250618.htm
# Processed record 287 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250618.htm
# Processed record 288 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250618.htm
# Processed record 289 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250618.htm
# Processed record 290 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250618.htm
# Processed record 291 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250618.htm
# Processed record 292 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250618.htm
# Processed record 293 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250618.htm
# Processed record 294 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250618.htm
# Processed record 295 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250618.htm
# Processed record 296 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250618.htm
# Processed record 297 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250618.htm
# Processed record 298 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250618.htm
# Processed record 299 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250618.htm
# Processed record 300 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250618.htm
# Processed record 301 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250618.htm
# Processed record 302 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250618.htm
# Processed record 303 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250618.htm
# Processed record 304 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250618.htm
# Processed record 305 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250618.htm
# Processed record 306 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250618.htm
# Processed record 307 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250618.htm
# Processed record 308 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250618.htm
# Processed record 309 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250618.htm
# Processed record 310 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250618.htm
# Processed record 311 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250618.htm
# Processed record 312 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250618.htm
# Processed record 313 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250618.htm
# Processed record 314 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250618.htm
# Processed record 315 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250618.htm
# Processed record 316 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250618.htm
# Processed record 317 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250618.htm
# Processed record 318 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250618.htm
# Processed record 319 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250618.htm
# Processed record 320 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250618.htm
# Processed record 321 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250618.htm
# Processed record 322 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250507a.htm
# Processed record 323 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250507a.htm
# Processed record 324 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250507a.htm
# Processed record 325 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250507a.htm
# Processed record 326 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250507a.htm
# Processed record 327 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250507a.htm
# Processed record 328 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250507a.htm
# Processed record 329 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250507a.htm
# Processed record 330 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250507a.htm
# Processed record 331 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250507.htm
# Processed record 332 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250507.htm
# Processed record 333 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250507.htm
# Processed record 334 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250507.htm
# Processed record 335 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250507.htm
# Processed record 336 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250507.htm
# Processed record 337 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250507.htm
# Processed record 338 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250507.htm
# Processed record 339 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250507.htm
# Processed record 340 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250507.htm
# Processed record 341 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250507.htm
# Processed record 342 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250507.htm
# Processed record 343 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250507.htm
# Processed record 344 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250507.htm
# Processed record 345 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250507.htm
# Processed record 346 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250507.htm
# Processed record 347 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250507.htm
# Processed record 348 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250507.htm
# Processed record 349 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250507.htm
# Processed record 350 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250507.htm
# Processed record 351 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250507.htm
# Processed record 352 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250507.htm
# Processed record 353 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250507.htm
# Processed record 354 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250507.htm
# Processed record 355 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250507.htm
# Processed record 356 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250507.htm
# Processed record 357 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250507.htm
# Processed record 358 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250507.htm
# Processed record 359 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250507.htm
# Processed record 360 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250507.htm
# Processed record 361 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250507.htm
# Processed record 362 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250507.htm
# Processed record 363 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250507.htm
# Processed record 364 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250507.htm
# Processed record 365 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250507.htm
# Processed record 366 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250319a.htm
# Processed record 367 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250319a.htm
# Processed record 368 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250319a.htm
# Processed record 369 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250319a.htm
# Processed record 370 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250319a.htm
# Processed record 371 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250319a.htm
# Processed record 372 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250319a.htm
# Processed record 373 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250319a.htm
# Processed record 374 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250319a.htm
# Processed record 375 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250319.htm
# Processed record 376 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250319.htm
# Processed record 377 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250319.htm
# Processed record 378 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250319.htm
# Processed record 379 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250319.htm
# Processed record 380 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250319.htm
# Processed record 381 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250319.htm
# Processed record 382 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250319.htm
# Processed record 383 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250319.htm
# Processed record 384 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250319.htm
# Processed record 385 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250319.htm
# Processed record 386 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250319.htm
# Processed record 387 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250319.htm
# Processed record 388 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250319.htm
# Processed record 389 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250319.htm
# Processed record 390 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250319.htm
# Processed record 391 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250319.htm
# Processed record 392 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250319.htm
# Processed record 393 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250319.htm
# Processed record 394 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250319.htm
# Processed record 395 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250319.htm
# Processed record 396 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250319.htm
# Processed record 397 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250319.htm
# Processed record 398 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250319.htm
# Processed record 399 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250319.htm
# Processed record 400 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250319.htm
# Processed record 401 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250319.htm
# Processed record 402 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250319.htm
# Processed record 403 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250319.htm
# Processed record 404 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250319.htm
# Processed record 405 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250319.htm
# Processed record 406 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250319.htm
# Processed record 407 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250319.htm
# Processed record 408 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250319.htm
# Processed record 409 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250319.htm
# Processed record 410 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250319.htm
# Processed record 411 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250319.htm
# Processed record 412 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20250319.htm
# Processed record 413 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250129a.htm
# Processed record 414 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250129a.htm
# Processed record 415 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250129a.htm
# Processed record 416 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250129a.htm
# Processed record 417 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250129a.htm
# Processed record 418 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250129a.htm
# Processed record 419 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250129a.htm
# Processed record 420 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250129a.htm
# Processed record 421 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20250129a.htm
# Processed record 422 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250129.htm
# Processed record 423 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250129.htm
# Processed record 424 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250129.htm
# Processed record 425 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250129.htm
# Processed record 426 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250129.htm
# Processed record 427 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250129.htm
# Processed record 428 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250129.htm
# Processed record 429 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250129.htm
# Processed record 430 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250129.htm
# Processed record 431 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250129.htm
# Processed record 432 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250129.htm
# Processed record 433 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250129.htm
# Processed record 434 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250129.htm
# Processed record 435 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250129.htm
# Processed record 436 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250129.htm
# Processed record 437 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20250129.htm
# Processed record 438 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250129.htm
# Processed record 439 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250129.htm
# Processed record 440 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250129.htm
# Processed record 441 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250129.htm
# Processed record 442 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250129.htm
# Processed record 443 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250129.htm
# Processed record 444 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250129.htm
# Processed record 445 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250129.htm
# Processed record 446 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250129.htm
# Processed record 447 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250129.htm
# Processed record 448 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250129.htm
# Processed record 449 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250129.htm
# Processed record 450 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250129.htm
# Processed record 451 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250129.htm
# Processed record 452 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250129.htm
# Processed record 453 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250129.htm
# Processed record 454 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20250129.htm
# Processed record 455 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20241218a.htm
# Processed record 456 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20241218a.htm
# Processed record 457 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20241218a.htm
# Processed record 458 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20241218a.htm
# Processed record 459 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20241218a.htm
# Processed record 460 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20241218a.htm
# Processed record 461 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20241218a.htm
# Processed record 462 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20241218a.htm
# Processed record 463 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20241218a.htm
# Processed record 464 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20241218a.htm
# ...
# Processed record 10298 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20260729.htm
# Processed record 10299 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20260729.htm
# Processed record 10300 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20260729.htm
# Processed record 10301 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20260729.htm
# Processed record 10302 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20260729.htm
# Processed record 10303 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20260729.htm
# Processed record 10304 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20260729.htm
# Processed record 10305 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20260729.htm
# Processed record 10306 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20260729.htm
# Processed record 10307 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20260729.htm
# Processed record 10308 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20260729.htm
# Processed record 10309 with URL: https://www.federalreserve.gov/newsevents/speech/warsh20260828a.htm
# Processed record 10310 with URL: https://www.federalreserve.gov/newsevents/speech/warsh20260828a.htm
# Processed record 10311 with URL: https://www.federalreserve.gov/newsevents/speech/warsh20260828a.htm
# Processed record 10312 with URL: https://www.federalreserve.gov/newsevents/speech/warsh20260828a.htm
# Processed record 10313 with URL: https://www.federalreserve.gov/newsevents/speech/warsh20260828a.htm
# Processed record 10314 with URL: https://www.federalreserve.gov/newsevents/speech/warsh20260828a.htm
# Processed record 10315 with URL: https://www.federalreserve.gov/newsevents/speech/warsh20260828a.htm
# Processed record 10316 with URL: https://www.federalreserve.gov/newsevents/speech/warsh20260828a.htm
# Processed record 10317 with URL: https://www.federalreserve.gov/newsevents/speech/warsh20260828a.htm
# Processed record 10318 with URL: https://www.federalreserve.gov/newsevents/speech/warsh20260828a.htm
# Processed record 10319 with URL: https://www.federalreserve.gov/newsevents/speech/warsh20260828a.htm
# Processed record 10320 with URL: https://www.federalreserve.gov/newsevents/speech/warsh20260828a.htm
# Processed record 10321 with URL: https://www.federalreserve.gov/newsevents/speech/warsh20260828a.htm
# Processed record 10322 with URL: https://www.federalreserve.gov/newsevents/speech/warsh20260828a.htm
# Processed record 10323 with URL: https://www.federalreserve.gov/newsevents/speech/warsh20260828a.htm
# Processed record 10324 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20171213a.htm
# Processed record 10325 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20171213a.htm
# Processed record 10326 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20171213a.htm
# Processed record 10327 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20171213a.htm
# Processed record 10328 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20171213a.htm
# Processed record 10329 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20171213a.htm
# Processed record 10330 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20171213a.htm
# Processed record 10331 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20171213a.htm
# Processed record 10332 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20171213a.htm
# Processed record 10333 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20171213a.htm
# Processed record 10334 with URL: https://www.federalreserve.gov/newsevents/speech/bowman20240305a.htm
# Processed record 10335 with URL: https://www.federalreserve.gov/newsevents/speech/waller20220324a.htm
# Processed record 10336 with URL: https://www.federalreserve.gov/newsevents/speech/waller20220324a.htm
# Processed record 10337 with URL: https://www.federalreserve.gov/newsevents/speech/waller20220324a.htm
# Processed record 10338 with URL: https://www.federalreserve.gov/newsevents/speech/waller20220324a.htm
# Processed record 10339 with URL: https://www.federalreserve.gov/newsevents/speech/waller20220324a.htm
# Processed record 10340 with URL: https://www.federalreserve.gov/newsevents/speech/waller20220324a.htm
# Processed record 10341 with URL: https://www.federalreserve.gov/newsevents/speech/waller20220324a.htm
# Processed record 10342 with URL: https://www.federalreserve.gov/newsevents/speech/waller20220324a.htm
# Processed record 10343 with URL: https://www.federalreserve.gov/newsevents/speech/waller20220324a.htm
# Processed record 10344 with URL: https://www.federalreserve.gov/newsevents/testimony/powell20210714a.htm
# Processed record 10345 with URL: https://www.federalreserve.gov/newsevents/testimony/powell20210714a.htm
# Processed record 10346 with URL: https://www.federalreserve.gov/newsevents/testimony/powell20210714a.htm
# Processed record 10347 with URL: https://www.federalreserve.gov/newsevents/testimony/powell20210714a.htm
# Processed record 10348 with URL: https://www.federalreserve.gov/newsevents/testimony/powell20210714a.htm
# Processed record 10349 with URL: https://www.federalreserve.gov/newsevents/testimony/powell20210714a.htm
# Processed record 10350 with URL: https://www.federalreserve.gov/newsevents/testimony/powell20210714a.htm
# Processed record 10351 with URL: https://www.federalreserve.gov/newsevents/testimony/powell20210714a.htm
# Processed record 10352 with URL: https://www.federalreserve.gov/newsevents/testimony/powell20210714a.htm
# Processed record 10353 with URL: https://www.federalreserve.gov/newsevents/testimony/powell20210714a.htm
# Processed record 10354 with URL: https://www.federalreserve.gov/newsevents/testimony/powell20210714a.htm
# Processed record 10355 with URL: https://www.federalreserve.gov/newsevents/testimony/powell20210714a.htm
# Processed record 10356 with URL: https://www.federalreserve.gov/newsevents/testimony/powell20210714a.htm
# Processed record 10357 with URL: https://www.federalreserve.gov/newsevents/testimony/powell20210714a.htm
# Processed record 10358 with URL: https://www.federalreserve.gov/newsevents/testimony/powell20210714a.htm
# Processed record 10359 with URL: https://www.federalreserve.gov/newsevents/testimony/powell20210714a.htm
# Processed record 10360 with URL: https://www.federalreserve.gov/newsevents/speech/fischer20150330a.htm
# Processed record 10361 with URL: https://www.federalreserve.gov/newsevents/speech/fischer20150330a.htm
# Processed record 10362 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20201105.htm
# Processed record 10363 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20201105.htm
# Processed record 10364 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20201105.htm
# Processed record 10365 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20201105.htm
# Processed record 10366 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20201105.htm
# Processed record 10367 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20201105.htm
# Processed record 10368 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20201105.htm
# Processed record 10369 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20201105.htm
# Processed record 10370 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20201105.htm
# Processed record 10371 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20201105.htm
# Processed record 10372 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20201105.htm
# Processed record 10373 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20201105.htm
# Processed record 10374 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20201105.htm
# Processed record 10375 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20201105.htm
# Processed record 10376 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20201105.htm
# Processed record 10377 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20201105.htm
# Processed record 10378 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20201105.htm
# Processed record 10379 with URL: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20201105.htm
# Processed record 10380 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20180926.htm
# Processed record 10381 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20180926.htm
# Processed record 10382 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20180926.htm
# Processed record 10383 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20180926.htm
# Processed record 10384 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20180926.htm
# Processed record 10385 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20180926.htm
# Processed record 10386 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20180926.htm
# Processed record 10387 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20180926.htm
# Processed record 10388 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20180926.htm
# Processed record 10389 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20180926.htm
# Processed record 10390 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20180926.htm
# Processed record 10391 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20180926.htm
# Processed record 10392 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20180926.htm
# Processed record 10393 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20180926.htm
# Processed record 10394 with URL: https://www.federalreserve.gov/monetarypolicy/fomcminutes20180926.htm
# Processed record 10395 with URL: https://www.federalreserve.gov/newsevents/speech/powell20250525a.htm
# Processed record 10396 with URL: https://www.federalreserve.gov/newsevents/speech/bowman20241011a.htm
# Processed record 10397 with URL: https://www.federalreserve.gov/newsevents/speech/clarida20210113a.htm
# Processed record 10398 with URL: https://www.federalreserve.gov/newsevents/speech/clarida20210113a.htm
# Processed record 10399 with URL: https://www.federalreserve.gov/newsevents/speech/clarida20210113a.htm
# Processed record 10400 with URL: https://www.federalreserve.gov/newsevents/speech/clarida20210113a.htm
# Processed record 10401 with URL: https://www.federalreserve.gov/newsevents/speech/clarida20210113a.htm
# Processed record 10402 with URL: https://www.federalreserve.gov/newsevents/speech/clarida20210113a.htm
# Processed record 10403 with URL: https://www.federalreserve.gov/newsevents/speech/clarida20210113a.htm
# Processed record 10404 with URL: https://www.federalreserve.gov/newsevents/speech/clarida20210113a.htm
# Processed record 10405 with URL: https://www.federalreserve.gov/newsevents/speech/clarida20210113a.htm
# Processed record 10406 with URL: https://www.federalreserve.gov/newsevents/speech/clarida20210113a.htm
# Processed record 10407 with URL: https://www.federalreserve.gov/newsevents/testimony/powell20170622a.htm
# Processed record 10408 with URL: https://www.federalreserve.gov/newsevents/testimony/powell20170622a.htm
# Processed record 10409 with URL: https://www.federalreserve.gov/newsevents/speech/fischer20150327a.htm
# Processed record 10410 with URL: https://www.federalreserve.gov/newsevents/speech/fischer20150327a.htm
# Processed record 10411 with URL: https://www.federalreserve.gov/newsevents/speech/fischer20150327a.htm
# Processed record 10412 with URL: https://www.federalreserve.gov/newsevents/speech/waller20260903a.htm
# Processed record 10413 with URL: https://www.federalreserve.gov/newsevents/speech/waller20260903a.htm
# Processed record 10414 with URL: https://www.federalreserve.gov/newsevents/speech/waller20260903a.htm
# Processed record 10415 with URL: https://www.federalreserve.gov/newsevents/speech/waller20260903a.htm
# Processed record 10416 with URL: https://www.federalreserve.gov/newsevents/speech/waller20260903a.htm
# Processed record 10417 with URL: https://www.federalreserve.gov/newsevents/speech/waller20260903a.htm
# Processed record 10418 with URL: https://www.federalreserve.gov/newsevents/speech/waller20260903a.htm
# Processed record 10419 with URL: https://www.federalreserve.gov/newsevents/speech/waller20260903a.htm
# Processed record 10420 with URL: https://www.federalreserve.gov/newsevents/speech/waller20260903a.htm
# Processed record 10421 with URL: https://www.federalreserve.gov/newsevents/speech/waller20260903a.htm
# Processed record 10422 with URL: https://www.federalreserve.gov/newsevents/speech/waller20260903a.htm
# Processed record 10423 with URL: https://www.federalreserve.gov/newsevents/speech/waller20260903a.htm
# Processed record 10424 with URL: https://www.federalreserve.gov/newsevents/speech/waller20260903a.htm
# Processed record 10425 with URL: https://www.federalreserve.gov/newsevents/speech/barr20260901a.htm
# Processed record 10426 with URL: https://www.federalreserve.gov/newsevents/speech/barr20260901a.htm
# Processed record 10427 with URL: https://www.federalreserve.gov/newsevents/speech/barr20260901a.htm
# Processed record 10428 with URL: https://www.federalreserve.gov/newsevents/speech/barr20260901a.htm
# Processed record 10429 with URL: https://www.federalreserve.gov/newsevents/speech/barr20260901a.htm
# Processed record 10430 with URL: https://www.federalreserve.gov/newsevents/speech/barr20260901a.htm
# Processed record 10431 with URL: https://www.federalreserve.gov/newsevents/speech/barr20260901a.htm
# Processed record 10432 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260916a.htm
# Processed record 10433 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260916a.htm
# Processed record 10434 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260916a.htm
# Processed record 10435 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260916a.htm
# Processed record 10436 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260916a.htm
# Processed record 10437 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260916a.htm
# Processed record 10438 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260916a.htm
# Processed record 10439 with URL: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260916a.htm
# Processed record 10440 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20260916.htm
# Processed record 10441 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20260916.htm
# Processed record 10442 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20260916.htm
# Processed record 10443 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20260916.htm
# Processed record 10444 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20260916.htm
# Processed record 10445 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20260916.htm
# Processed record 10446 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20260916.htm
# Processed record 10447 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20260916.htm
# Processed record 10448 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20260916.htm
# Processed record 10449 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20260916.htm
# Processed record 10450 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20260916.htm
# Processed record 10451 with URL: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20260916.htm

# %%
import json
from pathlib import Path

path_proj = Path.cwd().parent
path_data = path_proj / "data"

with open(path_data / "links_text.txt", "r", encoding="utf-8") as file:
    links_text = json.load(file)

links_text[0]
# Out:
# {'url': 'https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128a.htm',
#  'title': 'Federal Reserve issues FOMC statement',
#  'text': "\ufeff\nFederal Reserve Board - Federal Reserve issues FOMC statement\nSkip to main content\nAn official website of the United States Government\nHere's how you know\nOfficial websites use .gov\nA\n.gov\nwebsite belongs to an official government organization in the United States.\nSecure .gov websites use HTTPS\nA\nlock\n(\nLock\nLocked padlock icon\n) or\nhttps://\nmeans you've safely connected to the .gov website. Share sensitive information only on official, secure websites.\nBack to Home\nBoard of Governors of the Federal Reserve System\nStay Connected\nFederal Reserve Facebook Page\nFederal Reserve Instagram Page\nFederal Reserve YouTube Page\nFederal Reserve Flickr Page\nFederal Reserve LinkedIn Page\nFederal Reserve Threads Page\nFederal Reserve X Page\nFederal Reserve Bluesky Page\nSubscribe to RSS\nSubscribe to Email\nRecent Postings\nCalendar\nPublications\nSite Map\nA-Z index\nCareers\nFAQs\nVideos\nContact\nSearch\nSubmit Search Button\nAdvanced\nToggle Dropdown Menu\nMain Menu Toggle Button\nSections\nSearch Toggle Button\nSearch\nSearch Submit Button\nSubmit\nHome\nNews & Events\nPress Releases\nPress Release\nPDF\nJanuary 28, 2026\nFederal Reserve issues FOMC statement\nFor release at 2:00 p.m. EST\nShare\nAvailable indicators suggest that economic activity has been expanding at a solid pace. Job gains have remained low, and the unemployment rate has shown some signs of stabilization. Inflation remains somewhat elevated.\nThe Committee seeks to achieve maximum employment and inflation at the rate of 2 percent over the longer run. Uncertainty about the economic outlook remains elevated. The Committee is attentive to the risks to both sides of its dual mandate.\nIn support of its goals, the Committee decided to maintain the target range for the federal funds rate at 3‑1/2 to 3‑3/4 percent. In considering the extent and timing of additional adjustments to the target range for the federal funds rate, the Committee will carefully assess incoming data, the evolving outlook, and the balance of risks. The Committee is strongly committed to supporting maximum employment and returning inflation to its 2 percent objective.\nIn assessing the appropriate stance of monetary policy, the Committee will continue to monitor the implications of incoming information for the economic outlook. The Committee would be prepared to adjust the stance of monetary policy as appropriate if risks emerge that could impede the attainment of the Committee's goals. The Committee's assessments will take into account a wide range of information, including readings on labor market conditions, inflation pressures and inflation expectations, and financial and international developments.\nVoting for the monetary policy action were Jerome H. Powell, Chair; John C. Williams, Vice Chair; Michael S. Barr; Michelle W. Bowman; Lisa D. Cook; Beth M. Hammack; Philip N. Jefferson; Neel Kashkari; Lorie K. Logan; and Anna Paulson. Voting against this action were Stephen I. Miran and Christopher J. Waller, who preferred to lower the target range for the federal funds rate by 1/4 percentage point at this meeting.\nFor media inquiries, please email\n[email\xa0protected]\nor call 202-452-2955.\nImplementation Note issued January 28, 2026\nLast Update:\nJanuary 28, 2026",
#  'publication_date': '2026-01-28'}

# %%
len(links_text)
# Out:
# 1310

# %%
target_title = "Federal Reserve issues FOMC statement"

dates_fomc_statement = sorted(
    {
        item.get("publication_date")
        for item in links_text
        if item.get("title") == target_title and item.get("publication_date")
    }
)

dates_fomc_statement
# Out:
# ['2015-01-28',
#  '2015-03-18',
#  '2015-04-29',
#  '2015-06-17',
#  '2015-07-29',
#  '2015-09-17',
#  '2015-10-28',
#  '2015-12-16',
#  '2016-01-27',
#  '2016-03-16',
#  '2016-04-27',
#  '2016-06-15',
#  '2016-07-27',
#  '2016-09-21',
#  '2016-11-02',
#  '2016-12-14',
#  '2017-02-01',
#  '2017-03-15',
#  '2017-05-03',
#  '2017-06-14',
#  '2017-07-26',
#  '2017-09-20',
#  '2017-11-01',
#  '2017-12-13',
#  '2018-01-31',
#  '2018-03-21',
#  '2018-05-02',
#  '2018-06-13',
#  '2018-08-01',
#  '2018-09-26',
#  '2018-11-08',
#  '2018-12-19',
#  '2019-01-30',
#  '2019-03-20',
#  '2019-05-01',
#  '2019-06-19',
#  '2019-07-31',
#  '2019-09-18',
#  '2019-10-30',
#  '2019-12-11',
#  '2020-01-29',
#  '2020-03-03',
#  '2020-03-15',
#  '2020-03-23',
#  '2020-04-29',
#  '2020-06-10',
#  '2020-07-29',
#  '2020-09-16',
#  '2020-11-05',
#  '2020-12-16',
#  '2021-01-27',
#  '2021-03-17',
#  '2021-04-28',
#  '2021-06-16',
#  '2021-07-28',
#  '2021-09-22',
#  '2021-11-03',
#  '2021-12-15',
#  '2022-01-26',
#  '2022-03-16',
#  '2022-05-04',
#  '2022-06-15',
#  '2022-07-27',
#  '2022-09-21',
#  '2022-11-02',
#  '2022-12-14',
#  '2023-02-01',
#  '2023-03-22',
#  '2023-05-03',
#  '2023-06-14',
#  '2023-07-26',
#  '2023-09-20',
#  '2023-11-01',
#  '2023-12-13',
#  '2024-01-31',
#  '2024-03-20',
#  '2024-05-01',
#  '2024-06-12',
#  '2024-07-31',
#  '2024-09-18',
#  '2024-11-07',
#  '2024-12-18',
#  '2025-01-29',
#  '2025-03-19',
#  '2025-05-07',
#  '2025-06-18',
#  '2025-07-30',
#  '2025-09-17',
#  '2025-10-29',
#  '2025-12-10',
#  '2026-01-28',
#  '2026-03-18',
#  '2026-04-29',
#  '2026-06-17',
#  '2026-07-29',
#  '2026-09-16']

# %%
from datetime import datetime

start_date = dates_fomc_statement[0]
end_date = dates_fomc_statement[1]

print(start_date)
# Out:
# 2015-01-28

# %%
FRED_key = os.getenv('api_key_FRED')
api_key = FRED_key

print(api_key)
# Out:
# 72f7955268d6a65a486d6ca126771837

# %%
import requests

def get_fred_data(id_data: str) -> pd.DataFrame:
    url = f'https://api.stlouisfed.org/fred/series/observations?series_id={id_data}&api_key={api_key}&file_type=json'
    response = requests.get(url)

    # Check to make sure the request was successful
    if response.status_code != 200:
        raise Exception('Failed to get data:', response.status_code)
    else:
        # Convert the response to a dictionary
        data = response.json()

        # Extract the 'observations' field from the data
        observations = data['observations']

        # Create a pandas DataFrame from the observations
        df = pd.DataFrame(observations)

        return df

# df_upper = get_fred_data('DFEDTARL')
# df_upper.head(5)

# %%
def get_diff_federal_funds() -> pd.DataFrame:
    df_lower = get_fred_data('DFEDTARL')[["date", "value"]].copy()
    df_upper = get_fred_data('DFEDTARU')[["date", "value"]].copy()

    df_lower["date"] = pd.to_datetime(df_lower["date"])
    df_lower["value"] = df_lower["value"].astype(float)
    df_upper["date"] = pd.to_datetime(df_upper["date"])
    df_upper["value"] = df_upper["value"].astype(float)
    df_lower = df_lower.rename(columns={"value": "lower_value"})
    df_upper = df_upper.rename(columns={"value": "upper_value"})

    return df_lower.merge(df_upper, on="date", how="inner")

# %%
df_fred = get_diff_federal_funds()

df_fred.head(5)
# Out:
#         date  lower_value  upper_value
# 0 2008-12-16          0.0         0.25
# 1 2008-12-17          0.0         0.25
# 2 2008-12-18          0.0         0.25
# 3 2008-12-19          0.0         0.25
# 4 2008-12-20          0.0         0.25

# %%
statement_dates = pd.to_datetime(dates_fomc_statement).normalize()
df_fred_statement_dates = df_fred[
    df_fred["date"].dt.normalize().isin(statement_dates)
].copy()
df_fred_statement_dates = df_fred_statement_dates.sort_values("date")
# df_fred_statement_dates["lower_rate_change"] = df_fred_statement_dates["lower_value"].diff()
df_fred_statement_dates["upper_rate_change"] = df_fred_statement_dates["upper_value"].diff().fillna(0)

df_fred_statement_dates.to_csv(
    path_data / "df_fred_statement_dates.csv",
    index=False,
)
df_fred_statement_dates
# Out:
#            date  lower_value  upper_value  upper_rate_change
# 2234 2015-01-28          0.0         0.25                0.0
# 2283 2015-03-18          0.0         0.25                0.0
# 2325 2015-04-29          0.0         0.25                0.0
# 2374 2015-06-17          0.0         0.25                0.0
# 2416 2015-07-29          0.0         0.25                0.0
# ...         ...          ...          ...                ...
# 6301 2026-03-18          3.5         3.75                0.0
# 6343 2026-04-29          3.5         3.75                0.0
# 6392 2026-06-17          3.5         3.75                0.0
# 6434 2026-07-29          3.5         3.75                0.0
# 6483 2026-09-16          3.5         3.75                0.0
#
# [96 rows x 4 columns]

# %% [markdown]
# # Rodando analises no grafo

# %%
from graph_utils import drop_projection

# %%
start_date = dates_fomc_statement[0]
end_date = dates_fomc_statement[1]

# %%
def drop_connections_similar():
    query = """
    MATCH ()-[r:SIMILAR_TO]-()
    DELETE r
    RETURN count(r) AS removed_relationships
    """
    records, summary, keys = driver.execute_query(query)
    print(f"{records[0]['removed_relationships']} SIMILAR_TO relationships removed")

# %%
def create_similar_connections(
        start_date,
        end_date,
        similarity_cutoff=0.8
        ):
    drop_connections_similar()
    drop_projection('signal-cypher')

    query = """
    MATCH (source:Signal)
    WHERE source.embedding_signal IS NOT NULL
        AND source.date >= localdatetime($start_date)
        AND source.date < localdatetime($end_date)
    WITH gds.graph.project(
        'signal-cypher',
        source,
        null,
        {
            sourceNodeProperties: source {.embedding_signal},
            targetNodeProperties: null
        }
    ) as g
    RETURN g.graphName AS graph, g.nodeCount AS nodes, g.relationshipCount AS rels
    """
    records, summary, keys = driver.execute_query(query,
                                                parameters_= {
                                                    "start_date": start_date,
                                                    "end_date": end_date,
                                                    }
    )


    print(f"Created graph 'signal-cypher' with {records[0]['nodes']}")


    query = """
    CALL gds.knn.stream(
        'signal-cypher',
        {
            nodeProperties: [
                {embedding_signal: 'COSINE'}
            ],
            similarityCutoff: $similarity_cutoff,
            topK: 50,
            randomSeed: 42,
            concurrency: 1
        }
    )
    YIELD node1, node2, similarity
    WITH
        gds.util.asNode(node1) AS n1,
        gds.util.asNode(node2) AS n2,
        similarity
    WHERE elementId(n1) < elementId(n2)
    MERGE (n1)-[r:SIMILAR_TO]-(n2)
    SET r.score_similarity = similarity
    RETURN count(r) AS total_score_relationships
    """
    records, summary, keys = driver.execute_query(
        query,
        parameters_={"similarity_cutoff": similarity_cutoff},
    )
    print(f"Criadas {records[0]['total_score_relationships']} relationships SIMILAR_TO")

create_similar_connections(start_date, end_date)
# Out:
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# 2342 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 63
# Criadas 79 relationships SIMILAR_TO

# %%
def run_wcc(start_date, end_date):
    graph_name = "signal-wcc"
    drop_projection(graph_name)

    query = """
    MATCH (source:Signal)
    WHERE source.embedding_signal IS NOT NULL
        AND source.date >= localdatetime($start_date)
        AND source.date < localdatetime($end_date)

    OPTIONAL MATCH (source)-[r:SIMILAR_TO]-(target:Signal)
    WHERE target.embedding_signal IS NOT NULL
        AND target.date >= localdatetime($start_date)
        AND target.date < localdatetime($end_date)

    WITH gds.graph.project(
        'signal-wcc',
        source,
        target,
        {
            sourceNodeProperties: source {.embedding_signal, .score},
            targetNodeProperties: target {.embedding_signal, .score},
            relationshipProperties: r {.score_similarity}
        },
        {undirectedRelationshipTypes: ['*']}
    ) AS g
    RETURN g.graphName AS graph, g.nodeCount AS nodes, g.relationshipCount AS rels
    """
    records, summary, keys = driver.execute_query(
        query,
        parameters_={
            "start_date": start_date,
            "end_date": end_date,
        },
    )
    projection = records[0]
    print(
        f"Projection '{projection['graph']}': {projection['nodes']} nodes, "
        f"{projection['rels']} relationships"
    )

    query = """
    CALL gds.wcc.stream('signal-wcc')
    YIELD nodeId, componentId
    RETURN count(DISTINCT componentId) AS number_of_communities
    """
    records, summary, keys = driver.execute_query(query)
    number_of_communities = records[0]["number_of_communities"]
    print(f"{number_of_communities} communities")
    return number_of_communities

number_of_communities = run_wcc(start_date, end_date)
# Out:
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 63 nodes, 316 relationships
# 20 communities

# %%
def refine_similarity_cutoff(
    start_date,
    end_date,
    initial_cutoff=0.8,
    step=0.01,
    min_cutoff=0.1,
):
    similarity_cutoff = initial_cutoff

    while similarity_cutoff >= min_cutoff:
        create_similar_connections(start_date, end_date, similarity_cutoff)
        number_of_communities = run_wcc(start_date, end_date)

        if number_of_communities == 1:
            print(f"Single community reached with cutoff {similarity_cutoff:.2f}")
            return similarity_cutoff

        similarity_cutoff = round(similarity_cutoff - step, 10)

    raise RuntimeError(
        "A single community was not reached before the minimum cutoff."
    )

best_similarity_cutoff = refine_similarity_cutoff(start_date, end_date)
# Out:
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# 158 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 63
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 79 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Projection 'signal-wcc': 63 nodes, 316 relationships
# 20 communities
# 158 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 63
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 102 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 63 nodes, 408 relationships
# 18 communities
# 204 SIMILAR_TO relationships removed
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 63
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 124 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 63 nodes, 496 relationships
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# 13 communities
# 248 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 63
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 154 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 63 nodes, 616 relationships
# 9 communities
# 308 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 63
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 198 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 63 nodes, 792 relationships
# 6 communities
# 396 SIMILAR_TO relationships removed
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 63
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 253 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 63 nodes, 1012 relationships
# 4 communities
# 506 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 63
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 329 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Projection 'signal-wcc': 63 nodes, 1316 relationships
# 4 communities
# 658 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 63
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 414 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 63 nodes, 1656 relationships
# 2 communities
# 828 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 63
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 494 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 63 nodes, 1976 relationships
# 2 communities
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# 988 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 63
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 605 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 63 nodes, 2420 relationships
# 1 communities
# Single community reached with cutoff 0.71

# %%
def run_leiden_communities(graph_name="signal-wcc"):
    query = """
    CALL gds.leiden.stream(
        $graph_name,
        {
            relationshipWeightProperty: 'score_similarity',
            randomSeed: 42,
            concurrency: 1
        }
    )
    YIELD nodeId, communityId
    RETURN
        nodeId,
        communityId,
        gds.util.asNode(nodeId).score AS node_score
    ORDER BY communityId
    """

    records, summary, keys = driver.execute_query(
        query,
        parameters_={"graph_name": graph_name},
    )
    return pd.DataFrame([record.data() for record in records])


leiden_results = run_leiden_communities()
number_of_leiden_communities = leiden_results["communityId"].nunique()
print(f"Número de comunidades Leiden: {number_of_leiden_communities}")
leiden_results.head()
# Out:
# Número de comunidades Leiden: 5
#    nodeId  communityId  node_score
# 0   10801            1        -1.0
# 1    4434            1        -0.5
# 2    4442            1         0.5
# 3    4445            1        -1.0
# 4    4450            1        -0.5

# %%
def run_betweenness_centrality():
    query = """
    CALL gds.betweenness.stream(
        'signal-wcc',
        {relationshipWeightProperty: 'score_similarity'}
    )
    YIELD nodeId, score
    RETURN
        nodeId,
        score AS betweenness_centrality,
        gds.util.asNode(nodeId).score AS node_score
    ORDER BY betweenness_centrality DESC
    """
    records, summary, keys = driver.execute_query(query)
    return pd.DataFrame([record.data() for record in records])

betweenness_results = run_betweenness_centrality()
betweenness_results
# Out:
#     nodeId  betweenness_centrality  node_score
# 0    10788                   212.0         0.5
# 1    10767                   199.0        -1.0
# 2    10779                   178.0        -1.0
# 3     4454                   176.0         0.0
# 4    10798                   120.0         0.0
# ..     ...                     ...         ...
# 58   10782                     0.0        -0.5
# 59   10789                     0.0         0.5
# 60   10793                     0.0        -1.0
# 61   10797                     0.0        -0.5
# 62   10799                     0.0         0.0
#
# [63 rows x 3 columns]

# %%
def run_weighted_degree_centrality():
    query = """
    CALL gds.degree.stream(
        'signal-wcc',
        {relationshipWeightProperty: 'score_similarity',
         orientation: 'UNDIRECTED'}
    )
    YIELD nodeId, score
    RETURN nodeId, score AS degree_centrality
    ORDER BY degree_centrality DESC
    """
    records, summary, keys = driver.execute_query(query)
    return pd.DataFrame([record.data() for record in records])

degree_centrality_results = run_weighted_degree_centrality()
degree_centrality_results
# Out:
#     nodeId  degree_centrality
# 0     4446         133.343227
# 1    10801         125.590070
# 2     4433         117.320805
# 3     4436         115.810615
# 4     4454         111.714942
# ..     ...                ...
# 58   10783           9.665931
# 59   10798           8.975325
# 60   10782           6.654887
# 61   10799           6.078727
# 62   10797           5.876275
#
# [63 rows x 2 columns]

# %%
def run_weighted_pagerank():
    query = """
    CALL gds.pageRank.stream(
        'signal-wcc',
        {relationshipWeightProperty: 'score_similarity'}
    )
    YIELD nodeId, score
    RETURN nodeId, score AS pagerank_centrality
    ORDER BY pagerank_centrality DESC
    """
    records, summary, keys = driver.execute_query(query)
    return pd.DataFrame([record.data() for record in records])

pagerank_results = run_weighted_pagerank()
pagerank_results
# Out:
#     nodeId  pagerank_centrality
# 0     4446             1.904620
# 1    10801             1.820912
# 2     4454             1.678443
# 3     4433             1.671143
# 4     4436             1.659570
# ..     ...                  ...
# 58    4437             0.450137
# 59   10771             0.398110
# 60   10783             0.375931
# 61   10789             0.352396
# 62   10782             0.260755
#
# [63 rows x 2 columns]

# %%
def calculate_period_sentiment_score(start_date, end_date):
    degree_centrality_results = run_weighted_degree_centrality()
    pagerank_results = run_weighted_pagerank()
    centrality_results = run_betweenness_centrality().merge(
        degree_centrality_results,
        on="nodeId",
        how="left",
    ).merge(
        pagerank_results,
        on="nodeId",
        how="left",
    )
    valid_scores = centrality_results.dropna(
        subset=[
            "node_score",
            "betweenness_centrality",
            "degree_centrality",
            "pagerank_centrality",
        ]
    )

    if valid_scores.empty:
        raise ValueError("No nodes with centrality and sentiment scores are available.")

    graph_query = """
    CALL gds.graph.list()
    YIELD graphName, nodeCount, relationshipCount
    WHERE graphName = 'signal-wcc'
    RETURN nodeCount, relationshipCount
    """
    records, summary, keys = driver.execute_query(graph_query)
    graph_metrics = records[0]

    betweenness_weighted_sentiment = (
        valid_scores["node_score"] * valid_scores["betweenness_centrality"]
    ).sum() / valid_scores["betweenness_centrality"].sum()

    degree_weighted_sentiment = (
        valid_scores["node_score"] * valid_scores["degree_centrality"]
    ).sum() / valid_scores["degree_centrality"].sum()

    pagerank_weighted_sentiment = (
        valid_scores["node_score"] * valid_scores["pagerank_centrality"]
    ).sum() / valid_scores["pagerank_centrality"].sum()

    simple_mean_sentiment = valid_scores["node_score"].mean()

    leiden_results = run_leiden_communities()[["nodeId", "communityId"]]
    leiden_scores = leiden_results.merge(
        valid_scores,
        on="nodeId",
        how="inner",
    )
    if leiden_scores.empty:
        raise ValueError("No Leiden communities with centrality and sentiment scores are available.")

    community_scores = (
        leiden_scores.groupby("communityId", as_index=False)
        .agg(
            community_sentiment=("node_score", "mean"),
            community_size=("nodeId", "size"),
        )
    )
    leiden_equal_weight_sentiment = community_scores["community_sentiment"].mean()

    leiden_centrality_sentiments = []
    for centrality_column in [
        "betweenness_centrality",
        "degree_centrality",
        "pagerank_centrality",
    ]:
        community_indicator = (
            leiden_scores.groupby("communityId")
            .apply(
                lambda community: (
                    community["node_score"] * community[centrality_column]
                ).sum() / community[centrality_column].sum()
                if community[centrality_column].sum() > 0
                else float("nan"),
                include_groups=False,
            )
            .mean()
        )
        leiden_centrality_sentiments.append(community_indicator)

    (
        leiden_betweenness_weighted_sentiment,
        leiden_degree_weighted_sentiment,
        leiden_pagerank_weighted_sentiment,
    ) = leiden_centrality_sentiments

    return pd.DataFrame(
        [{
            "start_date": start_date,
            "end_date": end_date,
            "node_count": graph_metrics["nodeCount"],
            "relationship_count": graph_metrics["relationshipCount"],
            "number_of_leiden_communities": len(community_scores),
            "largest_leiden_community_size": community_scores["community_size"].max(),
            "leiden_equal_weight_sentiment": leiden_equal_weight_sentiment,
            "leiden_betweenness_weighted_sentiment": leiden_betweenness_weighted_sentiment,
            "leiden_degree_weighted_sentiment": leiden_degree_weighted_sentiment,
            "leiden_pagerank_weighted_sentiment": leiden_pagerank_weighted_sentiment,
            "simple_mean_sentiment": simple_mean_sentiment,
            "betweenness_weighted_sentiment": betweenness_weighted_sentiment,
            "degree_weighted_sentiment": degree_weighted_sentiment,
            "pagerank_weighted_sentiment": pagerank_weighted_sentiment,
        }]
    )

period_sentiment_scores = calculate_period_sentiment_score(start_date, end_date)
period_sentiment_scores
# Out:
#    start_date    end_date  node_count  relationship_count  \
# 0  2015-01-28  2015-03-18          63                2420
#
#    number_of_leiden_communities  largest_leiden_community_size  \
# 0                             5                             26
#
#    leiden_equal_weight_sentiment  leiden_betweenness_weighted_sentiment  \
# 0                      -0.327127                              -0.373007
#
#    leiden_degree_weighted_sentiment  leiden_pagerank_weighted_sentiment  \
# 0                         -0.373403                           -0.370562
#
#    simple_mean_sentiment  betweenness_weighted_sentiment  \
# 0              -0.309524                       -0.342177
#
#    degree_weighted_sentiment  pagerank_weighted_sentiment
# 0                  -0.423077                    -0.388588

# %%
def analyze_all_statement_periods(dates_fomc_statement):
    period_scores = []

    for start_date, end_date in zip(
        dates_fomc_statement[:-1],
        dates_fomc_statement[1:],
    ):
        print(f"Analyzing {start_date} to {end_date}")
        similarity_cutoff = refine_similarity_cutoff(start_date, end_date)
        period_score = calculate_period_sentiment_score(start_date, end_date)
        period_score["similarity_cutoff"] = similarity_cutoff
        period_scores.append(period_score)

    return pd.concat(period_scores, ignore_index=True)

all_period_sentiment_scores = analyze_all_statement_periods(dates_fomc_statement)
all_period_sentiment_scores
# Out:
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 893 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 114 nodes, 3572 relationships
# 4 communities
# 1786 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 114
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1081 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 114 nodes, 4324 relationships
# 4 communities
# 2162 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 114
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1314 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 114 nodes, 5256 relationships
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# 2 communities
# 2628 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 114
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1569 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 114 nodes, 6276 relationships
# 1 communities
# Single community reached with cutoff 0.72
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Analyzing 2021-03-17 to 2021-04-28
# 3138 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 116
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 225 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 116 nodes, 900 relationships
# 30 communities
# 450 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 116
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 288 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 116 nodes, 1152 relationships
# 24 communities
# 576 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 116
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 369 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 116 nodes, 1476 relationships
# 15 communities
# 738 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 116
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 474 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 116 nodes, 1896 relationships
# 9 communities
# 948 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 116
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 595 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 116 nodes, 2380 relationships
# 6 communities
# 1190 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 116
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 778 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 116 nodes, 3112 relationships
# 6 communities
# 1556 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 116
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1004 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 116 nodes, 4016 relationships
# 4 communities
# 2008 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 116
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1233 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 116 nodes, 4932 relationships
# 4 communities
# 2466 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 116
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1530 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 116 nodes, 6120 relationships
# 2 communities
# 3060 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 116
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1843 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 116 nodes, 7372 relationships
# 2 communities
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# 3686 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 116
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 2129 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Projection 'signal-wcc': 116 nodes, 8516 relationships
# 2 communities
# 4258 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 116
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 2414 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Projection 'signal-wcc': 116 nodes, 9656 relationships
# 1 communities
# Single community reached with cutoff 0.69
# Analyzing 2021-04-28 to 2021-06-16
# 4828 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 147
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 329 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 147 nodes, 1316 relationships
# 32 communities
# 658 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 147
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 423 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 147 nodes, 1692 relationships
# 22 communities
# 846 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 147
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 557 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 147 nodes, 2228 relationships
# 14 communities
# 1114 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 147
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 747 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 147 nodes, 2988 relationships
# 10 communities
# 1494 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 147
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1012 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 147 nodes, 4048 relationships
# 7 communities
# 2024 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 147
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1331 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 147 nodes, 5324 relationships
# 5 communities
# 2662 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 147
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1694 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 147 nodes, 6776 relationships
# 3 communities
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# 3388 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 147
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 2086 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 147 nodes, 8344 relationships
# 3 communities
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# 4172 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 147
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 2437 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Projection 'signal-wcc': 147 nodes, 9748 relationships
# 3 communities
# 4874 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 147
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 2822 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Projection 'signal-wcc': 147 nodes, 11288 relationships
# 2 communities
# 5644 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 147
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 3120 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Projection 'signal-wcc': 147 nodes, 12480 relationships
# 1 communities
# Single community reached with cutoff 0.70
# Analyzing 2021-06-16 to 2021-07-28
# 6240 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 102
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 214 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 102 nodes, 856 relationships
# 10 communities
# 428 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 102
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 283 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 102 nodes, 1132 relationships
# 8 communities
# 566 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 102
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# ...
# Criadas 132 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 93 nodes, 528 relationships
# 24 communities
# 264 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 93
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 166 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 93 nodes, 664 relationships
# 16 communities
# 332 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 93
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 244 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 93 nodes, 976 relationships
# 9 communities
# 488 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 93
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 315 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 93 nodes, 1260 relationships
# 7 communities
# 630 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 93
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 424 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 93 nodes, 1696 relationships
# 4 communities
# 848 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 93
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 562 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 93 nodes, 2248 relationships
# 2 communities
# 1124 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 93
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 722 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 93 nodes, 2888 relationships
# 2 communities
# 1444 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 93
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 936 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 93 nodes, 3744 relationships
# 1 communities
# Single community reached with cutoff 0.73
#     start_date    end_date  node_count  relationship_count  \
# 0   2015-01-28  2015-03-18          63                2420
# 1   2015-03-18  2015-04-29         114                6712
# 2   2015-04-29  2015-06-17          73                2236
# 3   2015-06-17  2015-07-29         106                5072
# 4   2015-07-29  2015-09-17          48                1556
# ..         ...         ...         ...                 ...
# 90  2026-01-28  2026-03-18         143                5304
# 91  2026-03-18  2026-04-29         140               11680
# 92  2026-04-29  2026-06-17         110                8136
# 93  2026-06-17  2026-07-29         115                5868
# 94  2026-07-29  2026-09-16          93                3744
#
#     number_of_leiden_communities  largest_leiden_community_size  \
# 0                              5                             26
# 1                              5                             32
# 2                              5                             27
# 3                              6                             25
# 4                              5                             12
# ..                           ...                            ...
# 90                             5                             42
# 91                             3                             60
# 92                             3                             46
# 93                             4                             46
# 94                             4                             28
#
#     leiden_equal_weight_sentiment  leiden_betweenness_weighted_sentiment  \
# 0                       -0.327127                              -0.373007
# 1                       -0.269858                              -0.267289
# 2                       -0.226465                              -0.095612
# 3                       -0.260305                              -0.278081
# 4                       -0.212381                              -0.333108
# ..                            ...                                    ...
# 90                       0.095971                               0.106509
# 91                       0.195038                               0.204362
# 92                       0.197947                               0.217080
# 93                       0.314849                               0.338493
# 94                       0.436071                               0.530815
#
#     leiden_degree_weighted_sentiment  leiden_pagerank_weighted_sentiment  \
# 0                          -0.373403                           -0.370562
# 1                          -0.289873                           -0.287589
# 2                          -0.217507                           -0.218550
# 3                          -0.287762                           -0.287993
# 4                          -0.270463                           -0.241466
# ..                               ...                                 ...
# 90                          0.097296                            0.098119
# 91                          0.194893                            0.195192
# 92                          0.217076                            0.216089
# 93                          0.387614                            0.365253
# 94                          0.490745                            0.486819
#
#     simple_mean_sentiment  betweenness_weighted_sentiment  \
# 0               -0.309524                       -0.342177
# 1               -0.271930                       -0.308037
# 2               -0.267123                       -0.306474
# 3               -0.297170                       -0.291188
# 4               -0.270833                       -0.303870
# ..                    ...                             ...
# 90               0.048951                        0.033708
# 91               0.246429                        0.202550
# 92               0.218182                        0.231968
# 93               0.365217                        0.382669
# 94               0.440860                        0.541388
#
#     degree_weighted_sentiment  pagerank_weighted_sentiment  similarity_cutoff
# 0                   -0.423077                    -0.388588               0.71
# 1                   -0.325871                    -0.311888               0.72
# 2                   -0.308506                    -0.299071               0.73
# 3                   -0.401612                    -0.366963               0.74
# 4                   -0.355758                    -0.325187               0.72
# ..                        ...                          ...                ...
# 90                   0.041395                     0.042228               0.74
# 91                   0.289401                     0.273228               0.69
# 92                   0.269910                     0.257003               0.69
# 93                   0.449213                     0.426557               0.72
# 94                   0.514080                     0.503127               0.73
#
# [95 rows x 15 columns]

# %%
all_period_sentiment_scores
# Out:
#     start_date    end_date  node_count  relationship_count  \
# 0   2015-01-28  2015-03-18          63                2420
# 1   2015-03-18  2015-04-29         114                6712
# 2   2015-04-29  2015-06-17          73                2236
# 3   2015-06-17  2015-07-29         106                5072
# 4   2015-07-29  2015-09-17          48                1556
# ..         ...         ...         ...                 ...
# 90  2026-01-28  2026-03-18         143                5304
# 91  2026-03-18  2026-04-29         140               11680
# 92  2026-04-29  2026-06-17         110                8136
# 93  2026-06-17  2026-07-29         115                5868
# 94  2026-07-29  2026-09-16          93                3744
#
#     number_of_leiden_communities  largest_leiden_community_size  \
# 0                              5                             26
# 1                              5                             32
# 2                              5                             27
# 3                              6                             25
# 4                              5                             12
# ..                           ...                            ...
# 90                             5                             42
# 91                             3                             60
# 92                             3                             46
# 93                             4                             46
# 94                             4                             28
#
#     leiden_equal_weight_sentiment  leiden_betweenness_weighted_sentiment  \
# 0                       -0.327127                              -0.373007
# 1                       -0.269858                              -0.267289
# 2                       -0.226465                              -0.095612
# 3                       -0.260305                              -0.278081
# 4                       -0.212381                              -0.333108
# ..                            ...                                    ...
# 90                       0.095971                               0.106509
# 91                       0.195038                               0.204362
# 92                       0.197947                               0.217080
# 93                       0.314849                               0.338493
# 94                       0.436071                               0.530815
#
#     leiden_degree_weighted_sentiment  leiden_pagerank_weighted_sentiment  \
# 0                          -0.373403                           -0.370562
# 1                          -0.289873                           -0.287589
# 2                          -0.217507                           -0.218550
# 3                          -0.287762                           -0.287993
# 4                          -0.270463                           -0.241466
# ..                               ...                                 ...
# 90                          0.097296                            0.098119
# 91                          0.194893                            0.195192
# 92                          0.217076                            0.216089
# 93                          0.387614                            0.365253
# 94                          0.490745                            0.486819
#
#     simple_mean_sentiment  betweenness_weighted_sentiment  \
# 0               -0.309524                       -0.342177
# 1               -0.271930                       -0.308037
# 2               -0.267123                       -0.306474
# 3               -0.297170                       -0.291188
# 4               -0.270833                       -0.303870
# ..                    ...                             ...
# 90               0.048951                        0.033708
# 91               0.246429                        0.202550
# 92               0.218182                        0.231968
# 93               0.365217                        0.382669
# 94               0.440860                        0.541388
#
#     degree_weighted_sentiment  pagerank_weighted_sentiment  similarity_cutoff
# 0                   -0.423077                    -0.388588               0.71
# 1                   -0.325871                    -0.311888               0.72
# 2                   -0.308506                    -0.299071               0.73
# 3                   -0.401612                    -0.366963               0.74
# 4                   -0.355758                    -0.325187               0.72
# ..                        ...                          ...                ...
# 90                   0.041395                     0.042228               0.74
# 91                   0.289401                     0.273228               0.69
# 92                   0.269910                     0.257003               0.69
# 93                   0.449213                     0.426557               0.72
# 94                   0.514080                     0.503127               0.73
#
# [95 rows x 15 columns]

# %%
output_file = path_data / "period_sentiment_scores.csv"
all_period_sentiment_scores.to_csv(output_file, index=False)
print(f"Saved results to {output_file}")
# Out:
# Saved results to c:\Users\ander\OneDrive\Cursos\MBA ciencia de dados EsalqUSP\tcc\data\period_sentiment_scores.csv

# %%
import pandas as pd

all_period_sentiment_scores = pd.read_csv(
    Path(path_data) / "period_sentiment_scores.csv",
    parse_dates=["start_date", "end_date"],
)
all_period_sentiment_scores.head()
# Out:
#   start_date   end_date  node_count  relationship_count  \
# 0 2015-01-28 2015-03-18          63                2420
# 1 2015-03-18 2015-04-29         114                6712
# 2 2015-04-29 2015-06-17          73                2236
# 3 2015-06-17 2015-07-29         106                5072
# 4 2015-07-29 2015-09-17          48                1556
#
#    number_of_leiden_communities  largest_leiden_community_size  \
# 0                             5                             26
# 1                             5                             32
# 2                             5                             27
# 3                             6                             25
# 4                             5                             12
#
#    leiden_equal_weight_sentiment  leiden_betweenness_weighted_sentiment  \
# 0                      -0.327127                              -0.373007
# 1                      -0.269858                              -0.267289
# 2                      -0.226465                              -0.095612
# 3                      -0.260305                              -0.278081
# 4                      -0.212381                              -0.333108
#
#    leiden_degree_weighted_sentiment  leiden_pagerank_weighted_sentiment  \
# 0                         -0.373403                           -0.370562
# 1                         -0.289873                           -0.287589
# 2                         -0.217507                           -0.218550
# 3                         -0.287762                           -0.287993
# 4                         -0.270463                           -0.241466
#
#    simple_mean_sentiment  betweenness_weighted_sentiment  \
# 0              -0.309524                       -0.342177
# 1              -0.271930                       -0.308037
# 2              -0.267123                       -0.306474
# 3              -0.297170                       -0.291188
# 4              -0.270833                       -0.303870
#
#    degree_weighted_sentiment  pagerank_weighted_sentiment  similarity_cutoff
# 0                  -0.423077                    -0.388588               0.71
# 1                  -0.325871                    -0.311888               0.72
# 2                  -0.308506                    -0.299071               0.73
# 3                  -0.401612                    -0.366963               0.74
# 4                  -0.355758                    -0.325187               0.72

# %%
import matplotlib.dates as mdates
from matplotlib.ticker import FuncFormatter, MaxNLocator

node_count_by_period = all_period_sentiment_scores.copy()
node_count_by_period['end_date'] = pd.to_datetime(node_count_by_period['end_date'])
node_count_by_period = node_count_by_period.sort_values('end_date')

month_abbreviations = [
    'jan.', 'fev.', 'mar.', 'abr.', 'maio', 'jun.',
    'jul.', 'ago.', 'set.', 'out.', 'nov.', 'dez.',
]

def format_date_pt_br(value, position):
    date = mdates.num2date(value)
    return f'{month_abbreviations[date.month - 1]}\n{date.year}'

fig, ax = plt.subplots(figsize=(10, 3), dpi=150)
fig.patch.set_facecolor('white')
ax.set_facecolor('white')

ax.plot(
    node_count_by_period['end_date'],
    node_count_by_period['node_count'],
    color='#0072B2',
    linewidth=2.2,
    marker='o',
    markersize=5.5,
    markerfacecolor='white',
    markeredgewidth=1.6,
    zorder=3,
)

for index, label in [
    (node_count_by_period['node_count'].idxmin(), 'Mínimo'),
    (node_count_by_period['node_count'].idxmax(), 'Máximo'),
]:
    period = node_count_by_period.loc[index]
    ax.annotate(
        f"{label}: {period['node_count']:.0f}",
        (period['end_date'], period['node_count']),
        xytext=(8, 10),
        textcoords='offset points',
        fontsize=8.5,
        color='#1A1A1A',
        bbox={'boxstyle': 'round,pad=0.25', 'facecolor': 'white', 'edgecolor': '#B3B3B3'},
    )

ax.set_title('Número de nós por período para os comunicados do FOMC', fontsize=13, fontweight='bold', pad=14)
ax.set_xlabel('Data final do período', fontsize=11, labelpad=8)
ax.set_ylabel('Número de nós', fontsize=11, labelpad=8)
ax.xaxis.set_major_formatter(FuncFormatter(format_date_pt_br))
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
ax.grid(axis='y', color='#D9D9D9', linewidth=0.8, alpha=0.8, zorder=0)
ax.grid(axis='x', visible=False)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color('#808080')
ax.spines['bottom'].set_color('#808080')
ax.tick_params(axis='both', labelsize=9, colors='#333333')
ax.margins(x=0.03, y=0.12)

plt.tight_layout()
figure_path = path_proj / 'TCC_latex' / 'figuras' / 'node_count_by_fomc_period.png'
fig.savefig(figure_path, dpi=300, bbox_inches='tight', facecolor='white')
print(f'Figure saved to {figure_path}')
plt.show()
# Out:
# Figure saved to c:\Users\ander\OneDrive\Cursos\MBA ciencia de dados EsalqUSP\tcc\TCC_latex\figuras\node_count_by_fomc_period.png

# %%
plot_data = all_period_sentiment_scores.copy()
plot_data['end_date'] = pd.to_datetime(plot_data['end_date'])
plot_data = plot_data.sort_values('end_date')

plot_definitions = [
    {
        'column': 'similarity_cutoff',
        'title': 'Limite de similaridade por período dos comunicados do FOMC',
        'ylabel': 'Limite de similaridade',
        'filename': 'similarity_cutoff_by_fomc_period.png',
        'color': '#D55E00',
        'integer_y': False,
    }
]

for plot_definition in plot_definitions:
    fig, ax = plt.subplots(figsize=(10, 3), dpi=150)
    fig.patch.set_facecolor('white')
    ax.set_facecolor('white')

    ax.plot(
        plot_data['end_date'],
        plot_data[plot_definition['column']],
        color=plot_definition['color'],
        linewidth=2.2,
        marker='o',
        markersize=5.5,
        markerfacecolor='white',
        markeredgewidth=1.6,
        zorder=3,
    )

    if plot_definition['column'] == 'similarity_cutoff':
        minimum_index = plot_data[plot_definition['column']].idxmin()
        maximum_index = plot_data[plot_definition['column']].idxmax()
        for index, label in [
            (minimum_index, 'Mínimo'),
            (maximum_index, 'Máximo'),
        ]:
            period = plot_data.loc[index]
            ax.annotate(
                f"{label}: {period[plot_definition['column']]:.2f}",
                (period['end_date'], period[plot_definition['column']]),
                xytext=(8, 10),
                textcoords='offset points',
                fontsize=8.5,
                color='#1A1A1A',
                bbox={
                    'boxstyle': 'round,pad=0.25',
                    'facecolor': 'white',
                    'edgecolor': '#B3B3B3',
                },
            )

    ax.set_title(plot_definition['title'], fontsize=13, fontweight='bold', pad=14)
    ax.set_xlabel('Data final do período', fontsize=11, labelpad=8)
    ax.set_ylabel(plot_definition['ylabel'], fontsize=11, labelpad=8)
    ax.xaxis.set_major_formatter(FuncFormatter(format_date_pt_br))
    if plot_definition['integer_y']:
        ax.yaxis.set_major_locator(MaxNLocator(integer=True))
    ax.grid(axis='y', color='#D9D9D9', linewidth=0.8, alpha=0.8, zorder=0)
    ax.grid(axis='x', visible=False)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_color('#808080')
    ax.spines['bottom'].set_color('#808080')
    ax.tick_params(axis='both', labelsize=9, colors='#333333')
    ax.margins(x=0.03, y=0.12)

    plt.tight_layout()
    figure_path = path_proj / 'TCC_latex' / 'figuras' / plot_definition['filename']
    fig.savefig(figure_path, dpi=300, bbox_inches='tight', facecolor='white')
    print(f"Figure saved to {figure_path}")
    plt.show()
# Out:
# Figure saved to c:\Users\ander\OneDrive\Cursos\MBA ciencia de dados EsalqUSP\tcc\TCC_latex\figuras\similarity_cutoff_by_fomc_period.png

# %%
def analyze_sentiment_evolution(all_period_sentiment_scores, federal_funds_rate):
    """Analyze centrality and community sentiment indicators over time."""

    all_period_sentiment_scores = all_period_sentiment_scores.copy()
    all_period_sentiment_scores['end_date'] = pd.to_datetime(
        all_period_sentiment_scores['end_date']
    )

    sentiment_evolution = all_period_sentiment_scores.merge(
        federal_funds_rate,
        left_on='end_date',
        right_on='date',
        how='left'
    )

    sentiment_labels = {
        "betweenness_weighted_sentiment": "Betweenness",
        "degree_weighted_sentiment": "Grau",
        "pagerank_weighted_sentiment": "PageRank",
        "leiden_equal_weight_sentiment": "Comunidades Leiden",
        "leiden_betweenness_weighted_sentiment": "Leiden + Betweenness",
        "leiden_degree_weighted_sentiment": "Leiden + Grau",
        "leiden_pagerank_weighted_sentiment": "Leiden + PageRank",
        "simple_mean_sentiment": "Média simples",
    }

    centrality_columns = [
        "leiden_equal_weight_sentiment",
        "degree_weighted_sentiment",
        "pagerank_weighted_sentiment",
        "betweenness_weighted_sentiment",
    ]

    community_centrality_columns = [
        "leiden_betweenness_weighted_sentiment",
        "leiden_degree_weighted_sentiment",
        "leiden_pagerank_weighted_sentiment",
        "simple_mean_sentiment",
    ]

    def plot_sentiment_indicators(columns, title, output_name, colors):
        fig, ax = plt.subplots(figsize=(16, 6))
        ax_twin = ax.twinx()
        ax_twin.set_zorder(ax.get_zorder() - 1)
        ax.patch.set_visible(False)

        for column, color in zip(columns, colors):
            ax.plot(
                sentiment_evolution['end_date'],
                sentiment_evolution[column],
                marker='o',
                markerfacecolor='white',
                markeredgewidth=1.5,
                linewidth=2.5,
                label=sentiment_labels[column],
                color=color,
                alpha=0.9,
            )

        ax_twin.plot(
            sentiment_evolution['end_date'],
            sentiment_evolution['upper_rate_change'],
            marker='s',
            markerfacecolor='white',
            markeredgewidth=1.5,
            linewidth=2.0,
            label='Variação da taxa de juros',
            color='tab:gray',
            alpha=0.8,
        )

        ax.set_xlabel('Data', fontsize=12)
        ax.set_ylabel('Indicadores de sentimento', fontsize=12)
        ax_twin.set_ylabel('Variação da taxa de juros', color='tab:gray', fontsize=12)
        ax.tick_params(axis='y', labelcolor='#333333')
        ax_twin.tick_params(axis='y', labelcolor='tab:gray')
        ax.set_title(title, fontsize=14, fontweight='bold')
        ax.grid(True, axis='y', color='#D9D9D9', alpha=0.7)
        ax.tick_params(axis='x', rotation=45)

        lines1, labels1 = ax.get_legend_handles_labels()
        lines2, labels2 = ax_twin.get_legend_handles_labels()
        ax.legend(
            lines1 + lines2,
            labels1 + labels2,
            loc='upper left',
            fontsize=10,
            frameon=False,
        )

        plt.tight_layout()
        output_path = path_proj / 'TCC_latex' / 'figuras' / output_name
        fig.savefig(output_path, dpi=300, bbox_inches='tight', facecolor='white')
        print(f'Figure saved to {output_path}')
        plt.show()

    plot_sentiment_indicators(
        centrality_columns,
        'Indicadores de sentimento por centralidade e comunidades Leiden',
        'sentiment_indicators_centrality_by_fomc_period.png',
        ['tab:purple', 'tab:orange', 'tab:red', 'tab:blue'],
    )

    plot_sentiment_indicators(
        community_centrality_columns,
        'Indicadores de sentimento por centralidade e comunidade',
        'sentiment_indicators_centrality_community_by_fomc_period.png',
        ['tab:cyan', 'tab:brown', 'tab:pink', 'tab:green'],
    )

    return sentiment_evolution

sentiment_evolution = analyze_sentiment_evolution(
    all_period_sentiment_scores,
    df_fred_statement_dates,
)
# Out:
# Figure saved to c:\Users\ander\OneDrive\Cursos\MBA ciencia de dados EsalqUSP\tcc\TCC_latex\figuras\sentiment_indicators_centrality_by_fomc_period.png
# Figure saved to c:\Users\ander\OneDrive\Cursos\MBA ciencia de dados EsalqUSP\tcc\TCC_latex\figuras\sentiment_indicators_centrality_community_by_fomc_period.png

# %%
sentiment_columns = [
    "betweenness_weighted_sentiment",
    "degree_weighted_sentiment",
    "pagerank_weighted_sentiment",
    "leiden_equal_weight_sentiment",
    "leiden_betweenness_weighted_sentiment",
    "leiden_degree_weighted_sentiment",
    "leiden_pagerank_weighted_sentiment",
    "simple_mean_sentiment",
]

sentiment_labels = {
    "betweenness_weighted_sentiment": "Betweenness",
    "degree_weighted_sentiment": "Grau",
    "pagerank_weighted_sentiment": "PageRank",
    "leiden_equal_weight_sentiment": "Comunidades Leiden",
    "leiden_betweenness_weighted_sentiment": "Leiden + Betweenness",
    "leiden_degree_weighted_sentiment": "Leiden + Grau",
    "leiden_pagerank_weighted_sentiment": "Leiden + PageRank",
    "simple_mean_sentiment": "Média simples",
}

correlation_data = sentiment_evolution[
    sentiment_columns + ["upper_rate_change"]
].dropna()

pearson_correlations = (
    correlation_data.corr(method="pearson")["upper_rate_change"]
    .drop("upper_rate_change")
    .rename("correlacao_pearson")
    .rename(index=sentiment_labels)
    .sort_values(ascending=False)
    .to_frame()
 )

pearson_correlations.index.name = "indicador"
pearson_correlations.round(3)
# Out:
#                       correlacao_pearson
# indicador
# Comunidades Leiden                 0.531
# Leiden + Grau                      0.530
# Leiden + PageRank                  0.527
# Média simples                      0.517
# Leiden + Betweenness               0.503
# PageRank                           0.503
# Grau                               0.500
# Betweenness                        0.487

# %%
# all_period_sentiment_scores = pd.read_csv(path_data / "period_sentiment_scores.csv")
# sentiment_evolution = analyze_sentiment_evolution(all_period_sentiment_scores, df_fred_statement_dates)
# sentiment_evolution[["end_date", "upper_rate_change"]].head()

# %% [markdown]
# # Selecionando limite de similaridade

# %%
saved_period_scores = pd.read_csv(path_data / 'period_sentiment_scores.csv')
constant_similarity_cutoff = saved_period_scores['similarity_cutoff'].median()
print(f'Corte de similaridade constante selecionado pela mediana: {constant_similarity_cutoff:.2f}')
# Out:
# Corte de similaridade constante selecionado pela mediana: 0.72

# %%
FIXED_SIMILARITY_CUTOFF = constant_similarity_cutoff


def analyze_all_statement_periods_fixed_cutoff(
    dates_fomc_statement,
    similarity_cutoff=FIXED_SIMILARITY_CUTOFF,
):
    period_scores = []

    for start_date, end_date in zip(
        dates_fomc_statement[:-1],
        dates_fomc_statement[1:],
    ):
        print(
            f"Analyzing {start_date} to {end_date} "
            f"with fixed similarity cutoff {similarity_cutoff:.2f}"
        )
        create_similar_connections(start_date, end_date, similarity_cutoff)
        run_wcc(start_date, end_date)
        period_score = calculate_period_sentiment_score(start_date, end_date)
        period_score["similarity_cutoff"] = similarity_cutoff
        period_scores.append(period_score)

    return pd.concat(period_scores, ignore_index=True)


fixed_period_sentiment_scores = analyze_all_statement_periods_fixed_cutoff(
    dates_fomc_statement
)

fixed_period_sentiment_scores.to_csv(
    path_data / "period_sentiment_scores_fixed.csv",
    index=False,
)

fixed_period_sentiment_scores.head()
# Out:
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Analyzing 2015-01-28 to 2015-03-18 with fixed similarity cutoff 0.72
# 1872 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 63
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 494 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 63 nodes, 1976 relationships
# 2 communities
# Analyzing 2015-03-18 to 2015-04-29 with fixed similarity cutoff 0.72
# 988 SIMILAR_TO relationships removed
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 114
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1678 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Projection 'signal-wcc': 114 nodes, 6712 relationships
# 1 communities
# Analyzing 2015-04-29 to 2015-06-17 with fixed similarity cutoff 0.72
# 3356 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 73
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 698 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 73 nodes, 2792 relationships
# 1 communities
# Analyzing 2015-06-17 to 2015-07-29 with fixed similarity cutoff 0.72
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# 1396 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 106
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1730 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Projection 'signal-wcc': 106 nodes, 6920 relationships
# 1 communities
# Analyzing 2015-07-29 to 2015-09-17 with fixed similarity cutoff 0.72
# 3460 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 48
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 389 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 48 nodes, 1556 relationships
# 1 communities
# Analyzing 2015-09-17 to 2015-10-28 with fixed similarity cutoff 0.72
# 778 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 118
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1853 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Projection 'signal-wcc': 118 nodes, 7412 relationships
# 2 communities
# Analyzing 2015-10-28 to 2015-12-16 with fixed similarity cutoff 0.72
# 3706 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 97
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1120 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 97 nodes, 4480 relationships
# 1 communities
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Analyzing 2015-12-16 to 2016-01-27 with fixed similarity cutoff 0.72
# 2240 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 64
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 698 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 64 nodes, 2792 relationships
# 1 communities
# Analyzing 2016-01-27 to 2016-03-16 with fixed similarity cutoff 0.72
# 1396 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 129
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1805 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Projection 'signal-wcc': 129 nodes, 7220 relationships
# 1 communities
# Analyzing 2016-03-16 to 2016-04-27 with fixed similarity cutoff 0.72
# 3610 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 74
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 914 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 74 nodes, 3656 relationships
# 1 communities
# Analyzing 2016-04-27 to 2016-06-15 with fixed similarity cutoff 0.72
# 1828 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 68
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 586 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 68 nodes, 2344 relationships
# 1 communities
# Analyzing 2016-06-15 to 2016-07-27 with fixed similarity cutoff 0.72
# 1172 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 80
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1150 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 80 nodes, 4600 relationships
# 1 communities
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Analyzing 2016-07-27 to 2016-09-21 with fixed similarity cutoff 0.72
# 2300 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 63
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 560 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 63 nodes, 2240 relationships
# 1 communities
# Analyzing 2016-09-21 to 2016-11-02 with fixed similarity cutoff 0.72
# 1120 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 114
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1595 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 114 nodes, 6380 relationships
# 1 communities
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Analyzing 2016-11-02 to 2016-12-14 with fixed similarity cutoff 0.72
# 3190 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 116
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1555 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 116 nodes, 6220 relationships
# 3 communities
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Analyzing 2016-12-14 to 2017-02-01 with fixed similarity cutoff 0.72
# 3110 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 110
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1682 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Projection 'signal-wcc': 110 nodes, 6728 relationships
# 1 communities
# Analyzing 2017-02-01 to 2017-03-15 with fixed similarity cutoff 0.72
# 3364 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 101
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1570 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 101 nodes, 6280 relationships
# 1 communities
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Analyzing 2017-03-15 to 2017-05-03 with fixed similarity cutoff 0.72
# 3140 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 83
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 944 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 83 nodes, 3776 relationships
# 2 communities
# Analyzing 2017-05-03 to 2017-06-14 with fixed similarity cutoff 0.72
# 1888 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 93
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1090 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 93 nodes, 4360 relationships
# 2 communities
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Analyzing 2017-06-14 to 2017-07-26 with fixed similarity cutoff 0.72
# 2180 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 88
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 912 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 88 nodes, 3648 relationships
# 2 communities
# Analyzing 2017-07-26 to 2017-09-20 with fixed similarity cutoff 0.72
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# 1824 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 47
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 328 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 47 nodes, 1312 relationships
# 2 communities
# Analyzing 2017-09-20 to 2017-11-01 with fixed similarity cutoff 0.72
# 656 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 137
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 2375 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Projection 'signal-wcc': 137 nodes, 9500 relationships
# 1 communities
# Analyzing 2017-11-01 to 2017-12-13 with fixed similarity cutoff 0.72
# 4750 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 65
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 794 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 65 nodes, 3176 relationships
# 2 communities
# Analyzing 2017-12-13 to 2018-01-31 with fixed similarity cutoff 0.72
# 1588 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 37
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 226 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 37 nodes, 904 relationships
# 1 communities
# Analyzing 2018-01-31 to 2018-03-21 with fixed similarity cutoff 0.72
# 452 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 79
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1030 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 79 nodes, 4120 relationships
# 1 communities
# Analyzing 2018-03-21 to 2018-05-02 with fixed similarity cutoff 0.72
# 2060 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 89
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1030 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 89 nodes, 4120 relationships
# 1 communities
# Analyzing 2018-05-02 to 2018-06-13 with fixed similarity cutoff 0.72
# 2060 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 69
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 563 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 69 nodes, 2252 relationships
# 2 communities
# Analyzing 2018-06-13 to 2018-08-01 with fixed similarity cutoff 0.72
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# 1126 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 76
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 763 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 76 nodes, 3052 relationships
# 2 communities
# Analyzing 2018-08-01 to 2018-09-26 with fixed similarity cutoff 0.72
# 1526 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 49
# ...
# Projection 'signal-wcc': 120 nodes, 6880 relationships
# 1 communities
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Analyzing 2025-09-17 to 2025-10-29 with fixed similarity cutoff 0.72
# 3440 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 220
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 3964 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Projection 'signal-wcc': 220 nodes, 15856 relationships
# 2 communities
# Analyzing 2025-10-29 to 2025-12-10 with fixed similarity cutoff 0.72
# 7928 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 152
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1666 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 152 nodes, 6664 relationships
# 2 communities
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Analyzing 2025-12-10 to 2026-01-28 with fixed similarity cutoff 0.72
# 3332 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 113
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1435 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 113 nodes, 5740 relationships
# 1 communities
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Analyzing 2026-01-28 to 2026-03-18 with fixed similarity cutoff 0.72
# 2870 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 143
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 2025 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 143 nodes, 8100 relationships
# 1 communities
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Analyzing 2026-03-18 to 2026-04-29 with fixed similarity cutoff 0.72
# 4050 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 140
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1911 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 140 nodes, 7644 relationships
# 2 communities
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Analyzing 2026-04-29 to 2026-06-17 with fixed similarity cutoff 0.72
# 3822 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 110
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1178 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 110 nodes, 4712 relationships
# 2 communities
# Analyzing 2026-06-17 to 2026-07-29 with fixed similarity cutoff 0.72
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# 2356 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 115
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1467 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 115 nodes, 5868 relationships
# 1 communities
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Analyzing 2026-07-29 to 2026-09-16 with fixed similarity cutoff 0.72
# 2934 SIMILAR_TO relationships removed
# Projection 'signal-cypher' removed
# Created graph 'signal-cypher' with 93
# Received notification from DBMS server: <GqlStatusObject gql_status='01N00', status_description='warn: feature deprecated. `schema` returned by the procedure `gds.graph.drop` is deprecated.', position=<SummaryInputPosition line=1, column=1, offset=0>, raw_classification='DEPRECATION', classification=<NotificationClassification.DEPRECATION: 'DEPRECATION'>, raw_severity='WARNING', severity=<NotificationSeverity.WARNING: 'WARNING'>, diagnostic_record={'_classification': 'DEPRECATION', '_severity': 'WARNING', '_position': {'offset': 0, 'line': 1, 'column': 1}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}> for query: 'CALL gds.graph.drop($projection_name)'
# Criadas 1171 relationships SIMILAR_TO
# Projection 'signal-wcc' removed
# Projection 'signal-wcc': 93 nodes, 4684 relationships
# 1 communities
#    start_date    end_date  node_count  relationship_count  \
# 0  2015-01-28  2015-03-18          63                1976
# 1  2015-03-18  2015-04-29         114                6712
# 2  2015-04-29  2015-06-17          73                2792
# 3  2015-06-17  2015-07-29         106                6920
# 4  2015-07-29  2015-09-17          48                1556
#
#    number_of_leiden_communities  largest_leiden_community_size  \
# 0                             5                             23
# 1                             5                             32
# 2                             4                             23
# 3                             4                             46
# 4                             5                             12
#
#    leiden_equal_weight_sentiment  leiden_betweenness_weighted_sentiment  \
# 0                      -0.327014                              -0.613690
# 1                      -0.269858                              -0.267289
# 2                      -0.254220                              -0.155078
# 3                      -0.257949                              -0.265675
# 4                      -0.212381                              -0.333108
#
#    leiden_degree_weighted_sentiment  leiden_pagerank_weighted_sentiment  \
# 0                         -0.393442                           -0.386918
# 1                         -0.289873                           -0.287589
# 2                         -0.293298                           -0.272651
# 3                         -0.276352                           -0.275937
# 4                         -0.270463                           -0.241466
#
#    simple_mean_sentiment  betweenness_weighted_sentiment  \
# 0              -0.309524                       -0.556655
# 1              -0.271930                       -0.308037
# 2              -0.267123                       -0.105348
# 3              -0.297170                       -0.320242
# 4              -0.270833                       -0.303870
#
#    degree_weighted_sentiment  pagerank_weighted_sentiment  similarity_cutoff
# 0                  -0.439581                    -0.401183               0.72
# 1                  -0.325871                    -0.311888               0.72
# 2                  -0.285179                    -0.279008               0.72
# 3                  -0.373133                    -0.349567               0.72
# 4                  -0.355758                    -0.325187               0.72

# %%
fixed_plot_data = fixed_period_sentiment_scores.copy()
fixed_plot_data["end_date"] = pd.to_datetime(fixed_plot_data["end_date"])
fixed_plot_data = fixed_plot_data.sort_values("end_date")

fig, ax = plt.subplots(figsize=(10, 3), dpi=150)
fig.patch.set_facecolor("white")
ax.set_facecolor("white")

ax.plot(
    fixed_plot_data["end_date"],
    fixed_plot_data["relationship_count"],
    color="#009E73",
    linewidth=2.2,
    marker="o",
    markersize=5.5,
    markerfacecolor="white",
    markeredgewidth=1.6,
    zorder=3,
)

ax.set_title(
    f"Número de conexões por período dos comunicados do FOMC "
    f"(corte fixo = {FIXED_SIMILARITY_CUTOFF:.2f})",
    fontsize=13,
    fontweight="bold",
    pad=14,
)
ax.set_xlabel("Data final do período", fontsize=11, labelpad=8)
ax.set_ylabel("Número de conexões", fontsize=11, labelpad=8)
ax.xaxis.set_major_formatter(FuncFormatter(format_date_pt_br))
ax.yaxis.set_major_locator(MaxNLocator(integer=True))
ax.grid(axis="y", color="#D9D9D9", linewidth=0.8, alpha=0.8, zorder=0)
ax.grid(axis="x", visible=False)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_color("#808080")
ax.spines["bottom"].set_color("#808080")
ax.tick_params(axis="both", labelsize=9, colors="#333333")
ax.margins(x=0.03, y=0.12)

plt.tight_layout()
fixed_figure_path = (
    path_proj
    / "TCC_latex"
    / "figuras"
    / "relationship_count_by_fomc_period_fixed_cutoff.png"
)
fig.savefig(fixed_figure_path, dpi=300, bbox_inches="tight", facecolor="white")
print(f"Figure saved to {fixed_figure_path}")
plt.show()
# Out:
# Figure saved to c:\Users\ander\OneDrive\Cursos\MBA ciencia de dados EsalqUSP\tcc\TCC_latex\figuras\relationship_count_by_fomc_period_fixed_cutoff.png

# %%
fixed_scores_for_correlation = pd.read_csv(
    path_data / "period_sentiment_scores_fixed.csv",
    parse_dates=["start_date", "end_date"],
)

fixed_sentiment_evolution = fixed_scores_for_correlation.merge(
    df_fred_statement_dates,
    left_on="end_date",
    right_on="date",
    how="left",
)

fixed_sentiment_columns = [
    "betweenness_weighted_sentiment",
    "degree_weighted_sentiment",
    "pagerank_weighted_sentiment",
    "leiden_equal_weight_sentiment",
    "leiden_betweenness_weighted_sentiment",
    "leiden_degree_weighted_sentiment",
    "leiden_pagerank_weighted_sentiment",
    "simple_mean_sentiment",
]

fixed_sentiment_labels = {
    "betweenness_weighted_sentiment": "Betweenness",
    "degree_weighted_sentiment": "Grau",
    "pagerank_weighted_sentiment": "PageRank",
    "leiden_equal_weight_sentiment": "Comunidades Leiden",
    "leiden_betweenness_weighted_sentiment": "Leiden + Betweenness",
    "leiden_degree_weighted_sentiment": "Leiden + Grau",
    "leiden_pagerank_weighted_sentiment": "Leiden + PageRank",
    "simple_mean_sentiment": "Média simples",
}

fixed_correlation_data = fixed_sentiment_evolution[
    fixed_sentiment_columns + ["upper_rate_change"]
].dropna()

fixed_pearson_correlations = (
    fixed_correlation_data.corr(method="pearson")["upper_rate_change"]
    .drop("upper_rate_change")
    .rename("correlacao_pearson")
    .rename(index=fixed_sentiment_labels)
    .sort_values(ascending=False)
    .to_frame()
 )

fixed_pearson_correlations.index.name = "indicador"
fixed_pearson_correlations.round(3)
# Out:
#                       correlacao_pearson
# indicador
# Betweenness                        0.531
# Média simples                      0.517
# Leiden + Betweenness               0.513
# PageRank                           0.506
# Grau                               0.501
# Leiden + Grau                      0.499
# Comunidades Leiden                 0.499
# Leiden + PageRank                  0.491

# %%
from shutil import copyfile

fixed_scores_for_graphs = pd.read_csv(
    path_data / "period_sentiment_scores_fixed.csv",
    parse_dates=["start_date", "end_date"],
)

analyze_sentiment_evolution(
    fixed_scores_for_graphs,
    df_fred_statement_dates,
)

figures_path = path_proj / "TCC_latex" / "figuras"
fixed_graph_names = {
    "sentiment_indicators_centrality_by_fomc_period.png": (
        "sentiment_indicators_centrality_by_fomc_period_fixed.png"
    ),
    "sentiment_indicators_centrality_community_by_fomc_period.png": (
        "sentiment_indicators_centrality_community_by_fomc_period_fixed.png"
    ),
}

for source_name, fixed_name in fixed_graph_names.items():
    source_path = figures_path / source_name
    fixed_path = figures_path / fixed_name
    copyfile(source_path, fixed_path)
    print(f"Figure saved to {fixed_path}")
# Out:
# Figure saved to c:\Users\ander\OneDrive\Cursos\MBA ciencia de dados EsalqUSP\tcc\TCC_latex\figuras\sentiment_indicators_centrality_by_fomc_period.png
# Figure saved to c:\Users\ander\OneDrive\Cursos\MBA ciencia de dados EsalqUSP\tcc\TCC_latex\figuras\sentiment_indicators_centrality_community_by_fomc_period.png
# Figure saved to c:\Users\ander\OneDrive\Cursos\MBA ciencia de dados EsalqUSP\tcc\TCC_latex\figuras\sentiment_indicators_centrality_by_fomc_period_fixed.png
# Figure saved to c:\Users\ander\OneDrive\Cursos\MBA ciencia de dados EsalqUSP\tcc\TCC_latex\figuras\sentiment_indicators_centrality_community_by_fomc_period_fixed.png
