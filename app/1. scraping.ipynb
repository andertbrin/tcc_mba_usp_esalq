# %%
import os
import sys
import json

from pathlib import Path


path_proj = Path.cwd().parent
path_data = os.path.join(path_proj, "data")


sys.path.append(os.path.join(path_proj, "utils"))

from fed_extract_links import (extract_index_fomc_materials,
                               get_fomc_links,
                               extract_speeches_testimony_links
                               )

from fed_extract_text import extract_text_from_link
from generate_llm import generate_gpt


# %load_ext autoreload
# %autoreload 2
# Out:
# Failed to read module file 'C:\Users\ander\AppData\Local\Programs\Python\Python314\Lib\re\_casefix.py' for module 're._casefix': UnicodeDecodeError
# Traceback (most recent call last):
#   File "c:\Users\ander\OneDrive\Cursos\MBA ciencia de dados EsalqUSP\tcc\.venv\Lib\site-packages\IPython\core\extensions.py", line 62, in load_extension
#     return self._load_extension(module_str)
#            ~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
#   File "c:\Users\ander\OneDrive\Cursos\MBA ciencia de dados EsalqUSP\tcc\.venv\Lib\site-packages\IPython\core\extensions.py", line 77, in _load_extension
#     mod = import_module(module_str)
#   File "C:\Users\ander\AppData\Local\Programs\Python\Python314\Lib\importlib\__init__.py", line 88, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1398, in _gcd_import
# ...

# %%
# from generate_llm import generate_gpt

# generate_gpt("What is the capital of France?")

# %%
# não é necessário rodar essa célula, pois os links já foram extraídos e salvos em arquivos JSON.
# extract_index_fomc_materials(path_data)

# %%
with open(os.path.join(path_data, "links_list.json"), "r") as f:
    links = json.load(f)

# %%
new_links = get_fomc_links()
new_links
# Out:
# ['https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128a1.htm',
#  'https://www.federalreserve.gov/monetarypolicy/fomcpressconf20260128.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128b.htm',
#  'https://www.federalreserve.gov/monetarypolicy/fomcminutes20260128.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/monetary20260318a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/monetary20260318a1.htm',
#  'https://www.federalreserve.gov/monetarypolicy/fomcpresconf20260318.htm',
#  'https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20260318.htm',
#  'https://www.federalreserve.gov/monetarypolicy/fomcminutes20260318.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/monetary20260429a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/monetary20260429a1.htm',
# ...

# %%
# checar se new_links já estão em links, se não estiverem, adicionar e salvar o arquivo JSON atualizado
for link in new_links:
    if link not in links:
        links.append(link)
        print(f"Novo link adicionado: {link}")

with open(os.path.join(path_data, "links_list.json"), "w") as f:
    json.dump(links, f, indent=2)
# Out:
# Novo link adicionado: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260916a.htm
# Novo link adicionado: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260916a1.htm
# Novo link adicionado: https://www.federalreserve.gov/monetarypolicy/fomcpresconf20260916.htm
# Novo link adicionado: https://www.federalreserve.gov/monetarypolicy/fomcprojtabl20260916.htm

# %%
result = extract_speeches_testimony_links(next_pages=5)

result["pages_scraped"], result["count"]
result["links"]
# Out:
# [{'title': 'The Economic Outlook and Some Comments on My Policy Communication',
#   'url': 'https://www.federalreserve.gov/newsevents/speech/waller20260903a.htm',
#   'date': '20260903',
#   'type': 'speech',
#   'page': 1},
#  {'title': 'Unlocking Opportunities for Workers and Entrepreneurs with a Criminal Record',
#   'url': 'https://www.federalreserve.gov/newsevents/speech/barr20260901a.htm',
#   'date': '20260901',
#   'type': 'speech',
#   'page': 1},
#  {'title': 'In Our Time',
#   'url': 'https://www.federalreserve.gov/newsevents/speech/warsh20260828a.htm',
#   'date': '20260828',
#   'type': 'speech',
#   'page': 1},
#  {'title': 'Outlook for the U.S. and Alaskan Economies',
#   'url': 'https://www.federalreserve.gov/newsevents/speech/cook20260805a.htm',
#   'date': '20260805',
#   'type': 'speech',
#   'page': 1},
#  {'title': 'Navigating Economic Shocks: A Monetary Policymaker’s Perspective',
# ...

# %%
# extraia somente a url do dicionário result["links"]

urls_speech = [link["url"] for link in result["links"]]

# adicione as urls extraídas à lista de links, se elas ainda não estiverem lá, e salve o arquivo JSON atualizado

for url in urls_speech:
    if url not in links:
        links.append(url)
        print(f"Novo link adicionado: {url}")

with open(os.path.join(path_data, "links_list.json"), "w") as f:
    json.dump(links, f, indent=2)

# %%
with open(os.path.join(path_data, "links_list.json"), "r") as f:
    links = json.load(f)

print(len(links))
# Out:
# 1310

# %%
from fed_extract_text import extract_pdf_links, extract_text_from_pdf

links_text_path = os.path.join(path_data, "links_text.txt")

try:
    with open(links_text_path, "r", encoding="utf-8") as f:
        links_text = json.load(f)
except FileNotFoundError:
    links_text = []

processed_urls = {item["url"] for item in links_text}


def is_press_release(url: str) -> bool:
    url_lower = url.lower()
    return "fomcpre" in url_lower or "pressreleases" in url_lower


def get_relevant_pdf_links(url: str) -> list[str]:
    pdf_links = extract_pdf_links(url, root="https://www.federalreserve.gov")
    return [
        link
        for link in pdf_links
        if "presc" in link.lower() or "longer" in link.lower()
    ]


def extract_result(url: str) -> dict:
    if not is_press_release(url):
        return extract_text_from_link(url)

    print(f"URL {url} é uma página de comunicado de imprensa, extraindo links de PDF...")
    pdf_links = get_relevant_pdf_links(url)
    print(f"Links de PDF encontrados: {pdf_links}")

    if not pdf_links:
        return extract_text_from_link(url)

    if len(pdf_links) > 1:
        # Seleciona somente o primeiro link de PDF encontrado
        print(f"Encontrados múltiplos links de PDF para a URL: {url}. Selecionando o primeiro link: {pdf_links[0]}")

        if "LongerRunGoals" in pdf_links[0]:
            pdf_links = [pdf_links[0]]
        else:
            raise ValueError(f"Encontrados múltiplos links de PDF para a URL: {url}")

    pdf_link = pdf_links[0]
    print(f"Extraindo texto do PDF {pdf_link}...")

    metadata = extract_text_from_link(url, title_pubdate=True)

    return {
        "text": extract_text_from_pdf(pdf_link),
        "title": metadata["title"],
        "publication_date": metadata["publication_date"],
    }


max_new_items = 99999
processed_now = 0

for i, url in enumerate(links, start=1):
    print(f"Processando URL {i}/{len(links)}: {url}")

    if url in processed_urls:
        print(f"URL {url} já foi processada, pulando...")
        continue

    result = extract_result(url)

    if result.get("text") is None:
        continue

    title = result.get("title") or ""
    if "implementation note" in title.lower():
        result["text"] = "NOT EXTRACTED - IMPLEMENTATION NOTE"

    links_text.append(
        {
            "url": url,
            "title": result.get("title"),
            "text": result.get("text"),
            "publication_date": result.get("publication_date"),
        }
    )
    processed_urls.add(url)

    with open(links_text_path, "w", encoding="utf-8") as f:
        json.dump(links_text, f, indent=2, ensure_ascii=False)

    processed_now += 1
    if processed_now >= max_new_items:
        break
# Out:
# Processando URL 1/1310: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128a.htm
# URL https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128a.htm já foi processada, pulando...
# Processando URL 2/1310: https://www.federalreserve.gov/monetarypolicy/fomcpressconf20260128.htm
# URL https://www.federalreserve.gov/monetarypolicy/fomcpressconf20260128.htm já foi processada, pulando...
# Processando URL 3/1310: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128b.htm
# URL https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128b.htm já foi processada, pulando...
# Processando URL 4/1310: https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128a1.htm
# URL https://www.federalreserve.gov/newsevents/pressreleases/monetary20260128a1.htm já foi processada, pulando...
# Processando URL 5/1310: https://www.federalreserve.gov/newsevents/pressreleases/monetary20251210a.htm
# ...

# %%
# extract_result(url)
